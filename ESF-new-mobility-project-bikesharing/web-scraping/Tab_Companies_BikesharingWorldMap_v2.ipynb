# %% [markdown]
# ## Tab+LatLong Companies from BikesharingWorldMap

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import pandas as pd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import fiona
from datetime import datetime
#import import_ipynb

# %% [markdown]
# ## Creation of 1. DataFrame - connection to BikesharingWorldMap html source code

# %%
#import LatLong_Tab_Mix_BikeshareMap_BikesharingWorldMap

# %%
# preparing URL – request GET and RESPONSE into soup
url = "https://bikesharingworldmap.com/"
response = requests.get(url)
print(response)
print(type(response.text))
html = response.text
soup = BeautifulSoup(html, "html.parser")
# Out:
# <Response [200]>
# <class 'str'>

# %%
# preparing data for cleaning

#soup.find("div", {"id": "legend"})
div_lst = soup.find_all("script")
type(div_lst)
# Out:
# bs4.element.ResultSet

# %%
# div_lst

# %%
# finding the indexes in the sheet for the given tag
# for idx, obj in enumerate(div_lst):
#     print(idx, obj)

# %%
soup.find_all("script")[7]
# Out:
# <script type="text/javascript">var systems ={"success":true,"message":"","result":[["acoruna","A Coru\u00f1a, Spain - Bicicoru\u00f1a",1,-8.39626,43.3723,396,2009,null,""],["aachen","Aachen, Germany - Call a Bike",3,6.092,50.7692,15,2011,2014,""],["aachen_velocity","Aachen, Germany - Velocity Aachen",1,6.0672,50.7789,300,2016,null,""],["aalborg","Aalborg, Denmark - City Bikes",3,9.92134,57.0437,170,2009,2014,""],["aalborg_donkey","Aalborg, Denmark - Donkey Republic",1,9.92116,57.0503,72,2017,null,""],["aarau","Aarau, Switzerland - ",2,8.04662,47.3874,null,null,null,""],["aarhus","Aarhus, Denmark - Aarhus Bycykel",3,10.2118,56.157,450,2005,2020,""],["aarhus_donkey","Aarhus, Denmark - Donkey Republic",1,10.2083,56.1575,444,2018,null,""],["aberdeen","Aberdeen, United Kingdom - Big Issue Sharebike",1,-2.10114,57.1541,450,2022,null,""],["abudhabi","Abu Dhabi, United Arab Emirates - ADCB Bikeshare",3,54.6144,24.4984,142,2014,2020,""],["abudhabi_careem","Abu Dhabi, United Arab Emirates - Careem BIKE",1,54.4465,24.4342,142,2021,null,""],["abudhabi_tier","Abu Dhabi, United Arab Emirates - TIER",1,54.4045,24.4939,40,2022,null,""],["acquaviva","Acquaviva delle Fonti, Italy - BiciViva",3,16.8436,40.8966,70,2012,2014,""],["adelaide_airbike","Adelaide, Australia - AirBike",1,138.583,-34.8997,20,2019,null,""],["adelaide_freebikes","Adelaide, Australia - Free Bikes",3,138.557,-34.9288,221,2005,2019,""],["adelaide","Adelaide, Australia - Neuron",1,138.557,-34.9288,150,2020,null,"CBD, North Adelaide, Norwood, St Peters and Payneham"],["adelaide_obike","Adelaide, Australia - obike",3,138.591,-34.9324,10,2017,2018,""],["adelaide_ofo","Adelaide, Australia - ofo",3,138.605,-34.922,50,2017,2018,""],["agadir","Agadir, Morocco - Basklit 2.0",1,-9.60892,30.423,25,2019,null,""],["agen","Agen, France - Tempovelo",1,0.620939,44.2076,73,2014,null,""],["agrigento","Agrigento, Italy - ",1,13.5844,37.3095,60,2023,null,""],["agrinio","Agrinio, Greece - ",2,21.4081,38.6264,81,null,null,""],["aguascalientes","Aguascalientes, Mexico - Mobike",1,-102.292,21.8793,500,2019,null,""],["agueda","\u00c1gueda, Portugal - be\u00c1gueda",1,-8.44664,40.5754,20,2020,null,""],["ahmedabad","Ahmedabad, India - MYBYK",1,72.5856,23.032,4000,2014,null,""],["aigio","Aigio, Greece - Cyclopolis Aigialeias",3,22.088,38.2484,45,2013,2014,""],["aigle","Aigle, Switzerland - Publibike",3,6.9619,46.3147,18,2010,2017,""],["aiud","Aiud , Romania - Bike Share",2,23.7185,46.3087,50,null,null,""],["aix","Aix-en-Provence, France - V'Hello",3,5.45402,43.5271,200,2007,2011,""],["akron","Akron & Barberton, United States - Summit Bike Share",1,-81.5183,41.0816,40,2017,null,""],["aksu","Aksu, China - Public Bicycle Rental",1,80.2658,41.1682,504,2013,null,""],["aktau","Aktau, Kazakhstan - Aqtaybike",1,51.1484,43.6501,180,2018,null,""],["alain","Al Ain, United Arab Emirates - BYKYstations UAE",3,55.7379,24.2377,29,2017,null,""],["alameda","Alameda, United States - Lime",3,-122.242,37.7643,400,2017,2019,""],["alba","Alba, Italy - Bicincitt\u00e0",3,8.0382,44.6986,14,2007,null,""],["alba_eazymov","Alba, Italy - Bus2Bike",3,8.0866,44.7012,320,2018,2019,""],["albacete","Albacete, Spain - Albabici",1,-1.8944,38.9958,139,2014,null,""],["albacete_onroll","Albacete, Spain - Albacete Bici",3,-1.85789,38.9937,112,2006,2012,""],["albano","Albano, Italy - Bikesharing",1,12.6587,41.7272,20,2013,null,""],["albany","Albany and Troy, United States - CDPHP Cycle!",4,-73.7497,42.6505,0,2017,null,""],["albuquerque","Albuquerque, United States - Pace",3,-106.668,35.0962,200,2015,2020,""],["alcala","Alcala de Guadaira, Spain - Tubici",3,-5.84747,37.3352,100,2008,2010,""],["alcazar","Alc\u00e1zar de San Juan, Spain - Alcazar Bici",3,-3.21011,39.3899,30,2008,2014,""],["alessandria","Alessandria, Italy - Bicincitt\u00e0",3,8.6162,44.9124,null,2010,2012,""],["algeciras","Algeciras-C\u00e1diz, Spain - Tubici",3,-5.44716,36.129,50,2008,2009,""],["alghero","Alghero, Italy - PedaliAMO",3,8.31717,40.5588,20,2013,2019,""],["algiers" ...

# %%
# data wrangling

unCleaned_data_0 = soup.find_all("script")[7].text


replacements = [
    (r"\\r\\n",""),
    (r"\\","")
]

for old, new in replacements:
    unCleaned_data_1 = re.sub(old, new, unCleaned_data_0)

unCleaned_data_1 = re.sub(r"\\r\\n","",unCleaned_data_0)
unCleaned_data_2 = re.sub(r"\\","",unCleaned_data_1)
len(unCleaned_data_2)

print(unCleaned_data_2[0:100])
print(unCleaned_data_2[-100:-1])

cleaned_data = unCleaned_data_2[13:-1]
cleaned_data
# Out:
# var systems ={"success":true,"message":"","result":[["acoruna","A Coruu00f1a, Spain - Bicicoruu00f1a
# 952,52.1056,96,2018,null,""]],"result2":{"thecount":9024552},"result3":{"lastmoddt":"30 Dec 2023"}}
# '{"success":true,"message":"","result":[["acoruna","A Coruu00f1a, Spain - Bicicoruu00f1a",1,-8.39626,43.3723,396,2009,null,""],["aachen","Aachen, Germany - Call a Bike",3,6.092,50.7692,15,2011,2014,""],["aachen_velocity","Aachen, Germany - Velocity Aachen",1,6.0672,50.7789,300,2016,null,""],["aalborg","Aalborg, Denmark - City Bikes",3,9.92134,57.0437,170,2009,2014,""],["aalborg_donkey","Aalborg, Denmark - Donkey Republic",1,9.92116,57.0503,72,2017,null,""],["aarau","Aarau, Switzerland - ",2,8.04662,47.3874,null,null,null,""],["aarhus","Aarhus, Denmark - Aarhus Bycykel",3,10.2118,56.157,450,2005,2020,""],["aarhus_donkey","Aarhus, Denmark - Donkey Republic",1,10.2083,56.1575,444,2018,null,""],["aberdeen","Aberdeen, United Kingdom - Big Issue Sharebike",1,-2.10114,57.1541,450,2022,null,""],["abudhabi","Abu Dhabi, United Arab Emirates - ADCB Bikeshare",3,54.6144,24.4984,142,2014,2020,""],["abudhabi_careem","Abu Dhabi, United Arab Emirates - Careem BIKE",1,54.4465,24.4342,142,2021,null,""],["abudhabi_tier","Abu Dhabi, United Arab Emirates - TIER",1,54.4045,24.4939,40,2022,null,""],["acquaviva","Acquaviva delle Fonti, Italy - BiciViva",3,16.8436,40.8966,70,2012,2014,""],["adelaide_airbike","Adelaide, Australia - AirBike",1,138.583,-34.8997,20,2019,null,""],["adelaide_freebikes","Adelaide, Australia - Free Bikes",3,138.557,-34.9288,221,2005,2019,""],["adelaide","Adelaide, Australia - Neuron",1,138.557,-34.9288,150,2020,null,"CBD, North Adelaide, Norwood, St Peters and Payneham"],["adelaide_obike","Adelaide, Australia - obike",3,138.591,-34.9324,10,2017,2018,""],["adelaide_ofo","Adelaide, Australia - ofo",3,138.605,-34.922,50,2017,2018,""],["agadir","Agadir, Morocco - Basklit 2.0",1,-9.60892,30.423,25,2019,null,""],["agen","Agen, France - Tempovelo",1,0.620939,44.2076,73,2014,null,""],["agrigento","Agrigento, Italy - ",1,13.5844,37.3095,60,2023,null,""],["agrinio","Agrinio, Greece - ",2,21.4081,38.6264,81,null,null,""],["aguascalientes","Aguascalientes, Mexico - Mobike",1,-102.292,21.8793,500,2019,null,""],["agueda","u00c1gueda, Portugal - beu00c1gueda",1,-8.44664,40.5754,20,2020,null,""],["ahmedabad","Ahmedabad, India - MYBYK",1,72.5856,23.032,4000,2014,null,""],["aigio","Aigio, Greece - Cyclopolis Aigialeias",3,22.088,38.2484,45,2013,2014,""],["aigle","Aigle, Switzerland - Publibike",3,6.9619,46.3147,18,2010,2017,""],["aiud","Aiud , Romania - Bike Share",2,23.7185,46.3087,50,null,null,""],["aix","Aix-en-Provence, France - V\'Hello",3,5.45402,43.5271,200,2007,2011,""],["akron","Akron & Barberton, United States - Summit Bike Share",1,-81.5183,41.0816,40,2017,null,""],["aksu","Aksu, China - Public Bicycle Rental",1,80.2658,41.1682,504,2013,null,""],["aktau","Aktau, Kazakhstan - Aqtaybike",1,51.1484,43.6501,180,2018,null,""],["alain","Al Ain, United Arab Emirates - BYKYstations UAE",3,55.7379,24.2377,29,2017,null,""],["alameda","Alameda, United States - Lime",3,-122.242,37.7643,400,2017,2019,""],["alba","Alba, Italy - Bicincittu00e0",3,8.0382,44.6986,14,2007,null,""],["alba_eazymov","Alba, Italy - Bus2Bike",3,8.0866,44.7012,320,2018,2019,""],["albacete","Albacete, Spain - Albabici",1,-1.8944,38.9958,139,2014,null,""],["albacete_onroll","Albacete, Spain - Albacete Bici",3,-1.85789,38.9937,112,2006,2012,""],["albano","Albano, Italy - Bikesharing",1,12.6587,41.7272,20,2013,null,""],["albany","Albany and Troy, United States - CDPHP Cycle!",4,-73.7497,42.6505,0,2017,null,""],["albuquerque","Albuquerque, United States - Pace",3,-106.668,35.0962,200,2015,2020,""],["alcala","Alcala de Guadaira, Spain - Tubici",3,-5.84747,37.3352,100,2008,2010,""],["alcazar","Alcu00e1zar de San Juan, Spain - Alcazar Bici",3,-3.21011,39.3899,30,2008,2014,""],["alessandria","Alessandria, Italy - Bicincittu00e0",3,8.6162,44.9124,null,2010,2012,""],["algeciras","Algeciras-Cu00e1diz, Spain - Tubici",3,-5.44716,36.129,50,2008,2009,""],["alghero","Alghero, Italy - PedaliAMO",3,8.31717,40.5588,20,2013,2019,""],["algiers","Algiers, Algeria - ",1,3.12016,36.7414,null,2023 ...

# %%
data = json.loads(cleaned_data)
data
# Out:
# {'success': True,
#  'message': '',
#  'result': [['acoruna',
#    'A Coruu00f1a, Spain - Bicicoruu00f1a',
#    1,
#    -8.39626,
#    43.3723,
#    396,
#    2009,
#    None,
#    ''],
#   ['aachen',
#    'Aachen, Germany - Call a Bike',
#    3,
#    6.092,
#    50.7692,
#    15,
#    2011,
#    2014,
#    ''],
#   ['aachen_velocity',
#    'Aachen, Germany - Velocity Aachen',
#    1,
#    6.0672,
#    50.7789,
#    300,
#    2016,
#    None,
#    ''],
#   ['aalborg',
#    'Aalborg, Denmark - City Bikes',
#    3,
#    9.92134,
#    57.0437,
#    170,
#    2009,
#    2014,
#    ''],
#   ['aalborg_donkey',
#    'Aalborg, Denmark - Donkey Republic',
#    1,
#    9.92116,
#    57.0503,
#    72,
#    2017,
#    None,
#    ''],
#   ['aarau',
#    'Aarau, Switzerland - ',
#    2,
#    8.04662,
#    47.3874,
#    None,
#    None,
#    None,
#    ''],
#   ['aarhus',
#    'Aarhus, Denmark - Aarhus Bycykel',
#    3,
#    10.2118,
#    56.157,
#    450,
#    2005,
#    2020,
#    ''],
#   ['aarhus_donkey',
#    'Aarhus, Denmark - Donkey Republic',
#    1,
#    10.2083,
#    56.1575,
#    444,
#    2018,
#    None,
#    ''],
#   ['aberdeen',
#    'Aberdeen, United Kingdom - Big Issue Sharebike',
#    1,
#    -2.10114,
#    57.1541,
#    450,
#    2022,
#    None,
#    ''],
#   ['abudhabi',
#    'Abu Dhabi, United Arab Emirates - ADCB Bikeshare',
#    3,
#    54.6144,
#    24.4984,
#    142,
#    2014,
#    2020,
#    ''],
#   ['abudhabi_careem',
#    'Abu Dhabi, United Arab Emirates - Careem BIKE',
#    1,
#    54.4465,
#    24.4342,
#    142,
#    2021,
#    None,
#    ''],
#   ['abudhabi_tier',
#    'Abu Dhabi, United Arab Emirates - TIER',
#    1,
#    54.4045,
#    24.4939,
#    40,
#    2022,
#    None,
#    ''],
#   ['acquaviva',
#    'Acquaviva delle Fonti, Italy - BiciViva',
#    3,
#    16.8436,
#    40.8966,
#    70,
#    2012,
#    2014,
#    ''],
#   ['adelaide_airbike',
#    'Adelaide, Australia - AirBike',
#    1,
#    138.583,
#    -34.8997,
#    20,
#    2019,
#    None,
#    ''],
#   ['adelaide_freebikes',
#    'Adelaide, Australia - Free Bikes',
#    3,
#    138.557,
#    -34.9288,
#    221,
#    2005,
#    2019,
#    ''],
#   ['adelaide',
#    'Adelaide, Australia - Neuron',
#    1,
#    138.557,
#    -34.9288,
#    150,
#    2020,
#    None,
#    'CBD, North Adelaide, Norwood, St Peters and Payneham'],
#   ['adelaide_obike',
#    'Adelaide, Australia - obike',
#    3,
#    138.591,
#    -34.9324,
#    10,
#    2017,
#    2018,
#    ''],
#   ['adelaide_ofo',
#    'Adelaide, Australia - ofo',
#    3,
#    138.605,
#    -34.922,
#    50,
#    2017,
#    2018,
#    ''],
#   ['agadir',
#    'Agadir, Morocco - Basklit 2.0',
#    1,
#    -9.60892,
#    30.423,
#    25,
#    2019,
#    None,
#    ''],
#   ['agen',
#    'Agen, France - Tempovelo',
#    1,
#    0.620939,
#    44.2076,
#    73,
#    2014,
#    None,
#    ''],
#   ['agrigento',
#    'Agrigento, Italy - ',
#    1,
#    13.5844,
#    37.3095,
#    60,
#    2023,
#    None,
#    ''],
#   ['agrinio', 'Agrinio, Greece - ', 2, 21.4081, 38.6264, 81, None, None, ''],
#   ['aguascalientes',
#    'Aguascalientes, Mexico - Mobike',
#    1,
#    -102.292,
#    21.8793,
#    500,
#    2019,
#    None,
#    ''],
#   ['agueda',
#    'u00c1gueda, Portugal - beu00c1gueda',
#    1,
#    -8.44664,
#    40.5754,
#    20,
#    2020,
#    None,
#    ''],
#   ['ahmedabad',
#    'Ahmedabad, India - MYBYK',
#    1,
#    72.5856,
#    23.032,
#    4000,
#    2014,
#    None,
#    ''],
#   ['aigio',
#    'Aigio, Greece - Cyclopolis Aigialeias',
#    3,
#    22.088,
#    38.2484,
#    45,
#    2013,
#    2014,
#    ''],
#   ['aigle',
#    'Aigle, Switzerland - Publibike',
#    3,
#    6.9619,
#    46.3147,
#    18,
#    2010,
#    2017,
#    ''],
#   ['aiud',
#    'Aiud , Romania - Bike Share',
#    2,
#    23.7185,
#    46.3087,
#    50,
#    None,
#    None,
#    ''],
#   ['aix',
#    "Aix-en-Provence, France - V'Hello",
#    3,
#    5.45402,
#    43.5271,
#    200,
#    2007,
#    2011,
#    ''],
#   ['akron',
#    'Akron & Barberton, United States - Summit Bike Share',
#    1,
#    -81.5183,
#    41.0816,
#    40,
#    2017,
#    None,
#    ''],
#   ['aksu',
#    'Aksu, China - Public Bicycle Rental',
#    1,
#    80.2658,
#    41.1682,
#    504,
#    2013,
#    None,
#    ''],
#   ['aktau',
#    'Aktau, Kazakhstan - Aqtaybike',
#    1,
#    51.1484,
#    43.6501,
#    180,
#    2018,
#    None,
#    ''],
#   ['alain',
#    'Al Ain, United Arab Emirates - BYKYstations UAE',
#    3,
#    55.7379,
#    24.2377,
#    29,
#    2017,
#    None,
#    ''],
#   ['alameda',
#    'Alameda, United States - Lime',
#    3,
#    -122.242,
#    37.7643,
#    400,
#    2017,
#    2019,
#    ''],
#   ['alba',
#    'Alba, Italy - Bicincittu00e0',
#    3,
#    8.0382,
#    44.6986,
#    14,
#    2007,
#    None,
#    ''],
#   ['alba_eazymov',
#    'Alba, Italy - Bus2Bike',
#    3,
#    8.0866,
#    44.7012,
#    320,
#    2018,
#    2019,
#    ''],
#   ['albacete',
#    'Albacete, Spain - Albabici',
#    1,
#    -1.8944,
#    38.9958,
#    139,
#    2014,
#    None,
#    ''],
#   ['albacete_onroll',
#    'Albacete, Spain - Albacete Bici',
#    3,
#    -1.85789,
#    38.9937,
#    112,
#    2006,
#    2012,
#    ''],
#   ['albano',
#    'Albano, Italy - Bikesharing',
#    1,
#    12.6587,
#    41.7272,
#    20,
#    2013,
#    None,
#    ''],
#   ['albany',
#    'Albany and Troy, United States - CDPHP Cycle!',
#    4,
#    -73.7497,
#    42.6505,
#    0,
#    2017,
#    None,
#    ''],
#   ['albuquerque',
#    'Albuquerque, United States - Pace',
#    3,
#    -106.668,
#    35.0962,
#    200,
#    2015,
#    2020,
#    ''],
#   ['alcala',
#    'Alcala de Guadaira, Spain - Tubici',
#    3,
#    -5.84747,
#    37.3352,
#    100,
#    2008,
#    2010,
#    ''],
#   ['alcazar',
#    'Alcu00e1zar de San Juan, Spain - Alcazar Bici',
#    3,
#    -3.21011,
#    39.3899,
#    30,
#    2008,
#    2014,
#    ''],
#   ['alessandria',
#    'Alessandria, Italy - Bicincittu00e0',
#    3,
#    8.6162,
#    44.9124,
#    None,
#    2010,
#    2012,
#    ''],
#   ['algeciras',
#    'Algeciras-Cu00e1diz, Spain - Tubici',
#    3,
#    -5.44716,
#    36.129,
#    50,
#    2008,
#    2009,
#    ''],
#   ['alghero',
#    'Alghero, Italy - PedaliAMO',
#    3,
#    8.31717,
#    40.5588,
#    20,
#    2013,
#    2019,
#    ''],
#   ['algiers',
#    'Algiers, Algeria - ',
#    1,
#    3.12016,
#    36.7414,
#    None,
#    2023,
#    None,
#    ''],
#   ['alhama',
#    'Alhama de Murcia, Spain - Onroll',
#    3,
#    -1.42685,
#    37.8483,
#    90,
#    2009,
#    2014,
#    ''],
#   ['alicante',
#    'Alicante, Spain - ALABICI',
#    3,
#    -0.48357,
#    38.3526,
#    None,
#    2010,
#    2014,
#    ''],
#   ['aljaraque',
#    'Aljaraque, Spain - Enbici',
#    3,
#    -7.02129,
#    37.2724,
#    70,
#    2010,
#    2014,
#    ''],
#   ['allentown',
#    'Allentown, United States - Zagster',
#    3,
#    -75.4915,
#    40.6061,
#    16,
#    2018,
#    2020,
#    ''],
#   ['almansa',
#    'Almansa, Spain - BiciAlmansa',
#    3,
#    -1.09378,
#    38.8709,
#    50,
#    2010,
#    2014,
#    'Albacete'],
#   ['almaty',
#    'Almaty, Kazakhstan - Almatybike',
#    1,
#    76.9055,
#    43.2644,
#    875,
#    2014,
#    None,
#    ''],
#   ['almeirim',
#    'Almeirim, Portugal - ALGIRA',
#    1,
#    -8.6211,
#    39.2069,
#    25,
#    2020,
#    None,
#    ''],
#   ['almelo',
#    'Almelo, Netherlands - Bondi',
#    1,
#    6.6644,
#    52.3563,
#    20,
#    2021,
#    None,
#    ''],
#   ['almendralejo',
#    'Almendralejo, Spain - Almendralejo en Bici',
#    3,
#    -6.40743,
#    38.6845,
#    75,
#    2010,
#    2012,
#    'Badajoz'],
#   ['almere_gosharing',
#    'Almere, Netherlands - GO Sharing',
#    1,
#    5.24055,
#    52.3701,
#    200,
#    2022,
#    None,
#    ''],
#   ['almere',
#    'Almere, Netherlands - TIER',
#    1,
#    5.2202,
#    52.3656,
#    300,
#    2022,
#    None,
#    ''],
#   ['almeria',
#    'Almeria, Spain - Tubici',
#    3,
#    -2.47192,
#    36.8357,
#    None,
#    2008,
#    2010,
#    'Universidad'],
#   ['almese', 'Almese, Italy - [TO]Bike', 1, 7.395, 45.118, 65, 2020, None, ''],
#   ['almetyevsk',
#    'Almetyevsk, Russia - GOBIKE',
#    1,
#    52.2949,
#    54.8968,
#    300,
#    2017,
#    None,
#    ''],
#   ['alpharetta',
#    'Alpharetta, United States - ',
#    3,
#    -84.302,
#    34.0382,
#    21,
#    2016,
#    2020,
#    ''],
#   ['alpignano',
#    'Alpignano, Italy - [TO]Bike',
#    3,
#    7.52426,
#    45.0958,
#    15,
#    2009,
#    2010,
#    ''],
#   ['altea',
#    'Altea, Spain - biciAltea',
#    3,
#    -0.0468206,
#    38.6022,
#    200,
#    2012,
#    2018,
#    ''],
#   ['alveringem_donkey',
#    'Alveringem and Lo, Belgium - Donkey Republic',
#    1,
#    2.72761,
#    50.9977,
#    16,
#    2023,
#    None,
#    'Alveringem, Lo-Reninge and Veurne'],
#   ['amboise',
#    'Amboise, France - Amboise - Vu00e9lo Libre Service',
#    1,
#    0.980549,
#    47.4041,
#    12,
#    2020,
#    None,
#    ''],
#   ['amersfoort_bird',
#    'Amersfoort, Netherlands - Bird ',
#    1,
#    5.3871,
#    52.1669,
#    150,
#    2022,
#    None,
#    ''],
#   ['amersfoort_gosharing',
#    'Amersfoort, Netherlands - GO Sharing',
#    3,
#    5.4089,
#    52.1549,
#    80,
#    2023,
#    None,
#    ''],
#   ['amersfoort',
#    'Amersfoort, Netherlands - TIER',
#    1,
#    5.3784,
#    52.1529,
#    127,
#    2021,
#    None,
#    ''],
#   ['amherst',
#    'Amherst et al, United States - ValleyBike',
#    5,
#    -72.5288,
#    42.3824,
#    130,
#    2018,
#    2022,
#    'Amherst, Northampton,  Holyoke, Springfield, Chicopee'],
#   ['amiens',
#    'Amiens, France - Velam',
#    1,
#    2.3011,
#    49.8909,
#    286,
#    2008,
#    None,
#    ''],
#   ['amman',
#    'Amman, Jordan - Darajtee',
#    1,
#    35.9845,
#    32.4916,
#    200,
#    2018,
#    None,
#    'Irbid'],
#   ['amorebieta',
#    'Amorebieta, Spain - Amorebiziz',
#    3,
#    -2.7347,
#    43.2213,
#    90,
#    2009,
#    2014,
#    'Vizcaya'],
#   ['amrum',
#    'Amrum, Germany - Amrum Bike-Sharing',
#    3,
#    8.39526,
#    54.6265,
#    20,
#    2019,
#    2020,
#    ''],
#   ['amsterdam_bondi',
#    'Amsterdam, Netherlands - Bondi',
#    1,
#    4.855,
#    52.3505,
#    25,
#    2021,
#    None,
#    ''],
#   ['amsterdam_cargoroo',
#    'Amsterdam, Netherlands - Cargoroo',
#    1,
#    4.9228,
#    52.3506,
#    50,
#    2021,
#    None,
#    ''],
#   ['amsterdam_donkeyre',
#    'Amsterdam, Netherlands - Donkey Republic',
#    1,
#    4.8947,
#    52.4121,
#    5,
#    2016,
#    None,
#    ''],
#   ['amsterdam_flickbike',
#    'Amsterdam, Netherlands - FlickBike',
#    1,
#    4.8335,
#    52.3719,
#    1000,
#    2017,
#    None,
#    ''],
#   ['amsterdam_hellobike',
#    'Amsterdam, Netherlands - Hello-Bike',
#    1,
#    4.87248,
#    52.3396,
#    200,
#    2017,
#    None,
#    ''],
#   ['amsterdam_obike',
#    'Amsterdam, Netherlands - oBike',
#    3,
#    4.89836,
#    52.3693,
#    2000,
#    2017,
#    2017,
#    ''],
#   ['amsterdam_urbee',
#    'Amsterdam, Netherlands - Urbee',
#    1,
#    4.9645,
#    52.3444,
#    160,
#    2016,
#    None,
#    'Amsterdam, Rotterdam, The Hague, Haarlem, Utretcht, Almere'],
#   ['amsterdam',
#    'Amsterdam-Schiphol, Netherlands - Your SchipholBIKE',
#    1,
#    4.75219,
#    52.3052,
#    36,
#    2013,
#    2016,
#    ''],
#   ['amstetten',
#    'Amstetten, Austria - nextbike Niederu00f6sterreich',
#    1,
#    14.8719,
#    48.1219,
#    34,
#    2009,
#    None,
#    ''],
#   ['anaheim',
#    'Anaheim, United States - Bike Nation',
#    3,
#    -117.908,
#    33.8312,
#    100,
#    2013,
#    2013,
#    ''],
#   ['anan_pippa',
#    'Anan, Japan - PiPPA',
#    1,
#    134.641,
#    33.9304,
#    None,
#    2020,
#    None,
#    ''],
#   ['anda',
#    'Anda, China - Anda City Public Bicycle',
#    1,
#    125.358,
#    46.4239,
#    300,
#    2017,
#    None,
#    ''],
#   ['malaga_enbici',
#    'Andalusia Technology Park, Spain - TUBICI',
#    3,
#    -4.55366,
#    36.7361,
#    100,
#    2009,
#    2016,
#    'PTA, Mu00e1laga'],
#   ['andorra',
#    'Andorra la Vella & Les Escaldes, Andorra - Cicland',
#    1,
#    1.53311,
#    42.5092,
#    60,
#    2014,
#    None,
#    ''],
#   ['andria',
#    'Andria, Italy - Andria in Bici',
#    3,
#    16.2948,
#    41.2257,
#    55,
#    2014,
#    2016,
#    ''],
#   ['angelholm',
#    'u00c4ngelholm, Sweden - Donkey Republic',
#    1,
#    12.8629,
#    56.2443,
#    150,
#    2018,
#    None,
#    ''],
#   ['angers_indigoweel',
#    'Angers, France - Indigo Weel',
#    3,
#    -0.54142,
#    47.4737,
#    800,
#    2017,
#    2020,
#    ''],
#   ['angers_ponybikes',
#    'Angers, France - Pony Bikes',
#    1,
#    -0.554552,
#    47.4735,
#    69,
#    2017,
#    None,
#    ''],
#   ['angers',
#    'Angers, France - Vu00e9locitu00e9+',
#    3,
#    -0.556569,
#    47.4651,
#    48,
#    2011,
#    2015,
#    ''],
#   ['angouleme',
#    'Angoulu00eame, France - Vu00e9lo Modalis',
#    1,
#    0.15052,
#    45.6456,
#    None,
#    2023,
#    None,
#    ''],
#   ['anji',
#    'Anji, China - Anji Public Bicycle',
#    1,
#    119.687,
#    30.6354,
#    3200,
#    2012,
#    None,
#    ''],
#   ['ankang_hightech',
#    'Ankang, China - Ankang High Tech Bicycle Service',
#    1,
#    109.013,
#    32.7036,
#    220,
#    2015,
#    None,
#    ''],
#   ['ankang',
#    'Ankang, China - Ankang Municipal Bicycle System',
#    1,
#    109.02,
#    32.69,
#    2700,
#    2016,
#    None,
#    ''],
#   ['ankara', 'Ankara, Turkey - ', 1, 32.8584, 39.9334, 25, 2022, None, ''],
#   ['annarbor',
#    'Ann Arbor, United States - ArborBike',
#    1,
#    -83.745,
#    42.2838,
#    125,
#    2014,
#    None,
#    ''],
#   ['annarbor_spin',
#    'Ann Arbor, United States - Spin',
#    1,
#    -83.7054,
#    42.2792,
#    89,
#    None,
#    None,
#    ''],
#   ['annapolis_bird',
#    'Annapolis, United States - Bird',
#    1,
#    -76.523,
#    38.985,
#    100,
#    2022,
#    None,
#    'Annapolis and Parole'],
#   ['annapolis',
#    'Annapolis, United States - Pace',
#    3,
#    -76.4873,
#    38.9801,
#    50,
#    2018,
#    2020,
#    ''],
#   ['annemasse_fredo',
#    'Annemasse Agglomeration, France - Fredo',
#    1,
#    6.23817,
#    46.1926,
#    30,
#    2023,
#    None,
#    'Annemasse, Ambilly, Gaillard, Cranves-Sales and Vu00e9traz-Monthoux'],
#   ['anniston',
#    'Anniston & Oxford, United States - VeoRide',
#    1,
#    -85.8281,
#    33.6403,
#    105,
#    2019,
#    None,
#    ''],
#   ['anqing', 'Anqing, China - ', 1, 117.063, 30.5481, 700, 2017, None, ''],
#   ['anqiu',
#    'Anqiu, China - Anqiu Public Bicycle',
#    1,
#    119.221,
#    36.5223,
#    1742,
#    2014,
#    None,
#    ''],
#   ['ansan',
#    'Ansan, South Korea - Pedalro',
#    3,
#    126.814,
#    37.3167,
#    1155,
#    2009,
#    2021,
#    ''],
#   ['anshun',
#    'Anshun, China - Meituan Bike',
#    3,
#    105.967,
#    26.2504,
#    None,
#    2017,
#    2020,
#    ''],
#   ['antalya',
#    'Antalya, Turkey - antbis',
#    1,
#    30.6882,
#    36.8873,
#    127,
#    2014,
#    None,
#    ''],
#   ['antequera',
#    'Antequera, Spain - ENbici',
#    3,
#    -4.56323,
#    37.0199,
#    58,
#    2010,
#    2014,
#    ''],
#   ['antibes',
#    "Antibes, France - Bik'Air",
#    1,
#    7.1102,
#    43.5864,
#    30,
#    None,
#    None,
#    'Antibes, Vallauris and Les Carnet'],
#   ['antwerp_donkey',
#    'Antwerp, Belgium - Donkey Republic',
#    1,
#    4.41471,
#    51.2318,
#    1650,
#    2022,
#    None,
#    '32 municipalities in the Antwerp metropolitan region'],
#   ['antwerp',
#    'Antwerp, Belgium - Velo Antwerpen',
#    1,
#    4.40277,
#    51.2206,
#    3906,
#    2011,
#    None,
#    ''],
#   ['anxi', 'Anxi, China - YouBike', 1, 118.188, 25.0478, 3088, 2016, None, ''],
#   ['anyang',
#    'Anyang, China - Anyang Public Bicycle Service',
#    1,
#    114.391,
#    36.1021,
#    5000,
#    2015,
#    None,
#    ''],
#   ['newtaipeicity_newbike',
#    'Aodi, Taiwan - NewBike',
#    1,
#    121.945,
#    25.019,
#    200,
#    2008,
#    None,
#    'Gongliao District'],
#   ['aosta',
#    "Aosta, Italy - C'entro in bici",
#    1,
#    7.31739,
#    45.7368,
#    66,
#    2005,
#    None,
#    ''],
#   ['aracaju',
#    'Aracaju, Brazil - Caju Bike',
#    3,
#    -37.0692,
#    -10.9065,
#    200,
#    2014,
#    2018,
#    ''],
#   ['arad',
#    'Arad, Romania - AradBikes',
#    2,
#    21.3159,
#    46.1737,
#    330,
#    None,
#    None,
#    ''],
#   ['aral', 'Aral, China - ', 1, 81.2788, 40.5425, 149, 2013, None, ''],
#   ['aranda',
#    'Aranda de Duero, Spain - Aranbici',
#    3,
#    -3.69286,
#    41.6636,
#    30,
#    2011,
#    2014,
#    ''],
#   ['aranjuez',
#    'Aranjuez, Spain - Aranbike',
#    1,
#    -3.60669,
#    40.0311,
#    25,
#    2009,
#    None,
#    ''],
#   ['arcata',
#    'Arcata, United States - Bike Share for Arcata & Humbolt State University',
#    3,
#    -124.084,
#    40.8753,
#    10,
#    2017,
#    2020,
#    ''],
#   ['arcata_tandem',
#    'Arcata, United States - Bike Share for Arcata & Humbolt State University',
#    1,
#    -124.084,
#    40.8753,
#    20,
#    2021,
#    None,
#    ''],
#   ['archea',
#    'Archea Olimpia, Greece - Cyclopolis Archea Olympia',
#    1,
#    21.6255,
#    37.6453,
#    50,
#    2013,
#    None,
#    ''],
#   ['arezzo',
#    'Arezzo, Italy - ARbike',
#    1,
#    11.8821,
#    43.4656,
#    43,
#    2011,
#    None,
#    ''],
#   ['arlington_uta_razor',
#    'Arlington, United States - Blue Duck',
#    1,
#    -97.1141,
#    32.7318,
#    250,
#    2022,
#    None,
#    ''],
#   ['arlington',
#    'Arlington, United States - Lime',
#    3,
#    -71.1542,
#    42.4142,
#    300,
#    2018,
#    2019,
#    ''],
#   ['arlington_ofo',
#    'Arlington, United States - ofo',
#    3,
#    -97.0924,
#    32.7479,
#    150,
#    2017,
#    2018,
#    ''],
#   ['arlington_uta',
#    'Arlington, United States - UTA Bike Share',
#    3,
#    -97.1141,
#    32.7318,
#    40,
#    2017,
#    2020,
#    ''],
#   ['armenia',
#    'Armenia, Colombia - ',
#    6,
#    -75.6753,
#    4.53514,
#    None,
#    None,
#    None,
#    ''],
#   ['armilla',
#    'Armilla, Spain - Tubici',
#    3,
#    -3.61793,
#    37.1401,
#    75,
#    2008,
#    2014,
#    ''],
#   ['arnhem',
#    'Arnhem, Netherlands - Cargoroo',
#    1,
#    5.9112,
#    51.981,
#    10,
#    2020,
#    None,
#    ''],
#   ['arradon',
#    'Arradon, France - Vu00e9lo Libre-Service',
#    3,
#    -2.82207,
#    47.6271,
#    10,
#    2018,
#    None,
#    ''],
#   ['arrecife', 'Arrecife, Spain - ', 2, -13.5518, 28.9664, 61, None, None, ''],
#   ['arteixo_nextbike',
#    'Arteixo, Spain - BiciArteixo',
#    1,
#    -8.50604,
#    43.307,
#    135,
#    2023,
#    None,
#    ''],
#   ['aruba',
#    'Aruba, Aruba - Green Bike',
#    1,
#    -70.0373,
#    12.5194,
#    73,
#    2017,
#    None,
#    'Oranjestad & Palm Beach'],
#   ['arzachena',
#    'Arzachena, Italy - Dott',
#    1,
#    9.3867,
#    41.0807,
#    2,
#    2023,
#    None,
#    ''],
#   ['as',
#    'u00c5s, Norway - Bygdebike',
#    1,
#    10.7927,
#    59.6633,
#    100,
#    2018,
#    None,
#    ''],
#   ['asan',
#    'Asan, South Korea - UBike',
#    1,
#    127.003,
#    36.7811,
#    90,
#    2011,
#    None,
#    ''],
#   ['asbury',
#    'Asbury Park, United States - Asbury Park Bike Share',
#    3,
#    -74.0012,
#    40.2243,
#    30,
#    2017,
#    2020,
#    ''],
#   ['ascoli',
#    'Ascoli Piceno, Italy - Bicincittu00e0',
#    1,
#    13.5788,
#    42.8553,
#    20,
#    2013,
#    None,
#    ''],
#   ['ashbourne',
#    'Ashbourne, Ireland - Moby Move',
#    1,
#    -6.3969,
#    53.5095,
#    33,
#    None,
#    2023,
#    ''],
#   ['ashland',
#    'Ashland, United States - Rogue Bike Share',
#    3,
#    -122.853,
#    42.3311,
#    43,
#    2015,
#    2020,
#    ''],
#   ['asker', 'Asker, Norway - TIER', 1, 10.4336, 59.8337, 58, 2022, None, ''],
#   ['aspen',
#    'Aspen and Mid-Valley, United States - WE-cycle',
#    1,
#    -106.916,
#    39.2843,
#    376,
#    2013,
#    None,
#    'Aspen, Basalt, Willits, El Jebel, Snowmass'],
#   ['asti_vaimoo', 'Asti, Italy - ', 2, 8.204, 44.9017, 80, None, None, ''],
#   ['asti',
#    'Asti, Italy - GIMME BIKE',
#    3,
#    8.20679,
#    44.9011,
#    25,
#    2008,
#    2014,
#    ''],
#   ['asuncion',
#    'Asunciu00f3n, Paraguay - Asu Viva',
#    1,
#    -57.6337,
#    -25.2826,
#    50,
#    2018,
#    None,
#    ''],
#   ['athens',
#    'Athens, Greece - ',
#    2,
#    23.7301,
#    37.978,
#    1000,
#    None,
#    None,
#    'Municipality'],
#   ['athens_athensbikes',
#    'Athens, Greece - AthensBikes',
#    3,
#    23.7135,
#    37.9773,
#    10,
#    2016,
#    2019,
#    ''],
#   ['athens_cyclopolis',
#    'Athens, Greece - Cyclopolis',
#    3,
#    23.6769,
#    37.9459,
#    60,
#    2013,
#    2015,
#    'Muscat and Taurus Communities'],
#   ['athens_maroussi',
#    'Athens, Greece - Cyclopolis Maroussi',
#    1,
#    23.8071,
#    38.0553,
#    33,
#    2013,
#    None,
#    'Maroussi'],
#   ['athens_neassmyrnis',
#    'Athens, Greece - Cyclopolis Neas Smyrnis',
#    1,
#    23.7124,
#    37.9437,
#    45,
#    2013,
#    None,
#    'Neas Smyrnis District'],
#   ['athens_keratsini',
#    'Athens, Greece - EasyBike Keratsini-Drapetsona',
#    3,
#    23.6253,
#    37.9473,
#    24,
#    2013,
#    2015,
#    'Keratsini-Drapetsona District'],
#   ['athens_ebyheron',
#    'Athens, Greece - eBikeShare by Heron',
#    1,
#    23.7122,
#    37.961,
#    100,
#    2018,
#    None,
#    'Kallithea, Tavros, Kifissia, Nea Smyrna'],
#   ['athens_uga',
#    'Athens, United States - Bulldog Bike Share',
#    1,
#    -83.3795,
#    33.9572,
#    158,
#    None,
#    None,
#    'University of Georgia'],
#   ['atlanta_helbiz',
#    'Atlanta, United States - Helbiz',
#    2,
#    -84.3942,
#    33.7523,
#    None,
#    None,
#    None,
#    ''],
#   ['atlanta_jump',
#    'Atlanta, United States - Jump',
#    3,
#    -84.3867,
#    33.7618,
#    1000,
#    2019,
#    2019,
#    ''],
#   ['atlanta_ofo',
#    'Atlanta, United States - ofo',
#    3,
#    -84.381,
#    33.7757,
#    None,
#    2018,
#    2018,
#    ''],
#   ['atlanta_relay',
#    'Atlanta, United States - Relay',
#    3,
#    -84.3878,
#    33.7493,
#    327,
#    2016,
#    2023,
#    ''],
#   ['atlanta_viacyclegt',
#    'Atlanta, United States - Viacycle@GT',
#    3,
#    -84.3967,
#    33.7754,
#    35,
#    2011,
#    2013,
#    ''],
#   ['atlanta_zagster',
#    'Atlanta, United States - Zagster',
#    3,
#    -84.3925,
#    33.7471,
#    None,
#    2016,
#    2020,
#    ''],
#   ['aubonne',
#    'Aubonne, Switzerland - Pick-e-Bike',
#    1,
#    6.38745,
#    46.4917,
#    35,
#    2021,
#    None,
#    ''],
#   ['auckland_jump',
#    'Auckland, New Zealand - Lime',
#    1,
#    174.759,
#    -36.8616,
#    500,
#    2020,
#    None,
#    ''],
#   ['auckland_nextbike',
#    'Auckland, New Zealand - Nextbike',
#    3,
#    174.755,
#    -36.8719,
#    170,
#    2008,
#    2010,
#    ''],
#   ['auckland_nextbikeii',
#    'Auckland, New Zealand - Nextbike II',
#    3,
#    174.764,
#    -36.8412,
#    45,
#    2013,
#    2022,
#    ''],
#   ['auckland_onzo',
#    'Auckland, New Zealand - Onzo',
#    3,
#    174.756,
#    -36.8447,
#    1250,
#    2017,
#    2020,
#    ''],
#   ['augsburg',
#    'Augsburg, Germany - swaRad',
#    1,
#    10.8985,
#    48.3646,
#    439,
#    2011,
#    None,
#    ''],
#   ['aurora_rivercities',
#    'Aurora and Lawrenceburg, United States - River Cities Bike Share',
#    1,
#    -84.9003,
#    39.0565,
#    30,
#    2017,
#    None,
#    ''],
#   ['aurora_limebike',
#    'Aurora, United States - Lime',
#    3,
#    -104.838,
#    39.73,
#    1500,
#    2017,
#    2018,
#    ''],
#   ['aurora_ofo',
#    'Aurora, United States - ofo',
#    3,
#    -104.837,
#    39.7391,
#    100,
#    2017,
#    2018,
#    ''],
#   ['aurora_spin',
#    'Aurora, United States - Spin',
#    3,
#    -104.847,
#    39.7333,
#    250,
#    2017,
#    2018,
#    ''],
#   ['aurora_zagster',
#    'Aurora, United States - Zagster',
#    3,
#    -88.3167,
#    41.7605,
#    18,
#    2016,
#    2020,
#    ''],
#   ['austin_jump',
#    'Austin, United States - Jump by Lime',
#    1,
#    -97.7443,
#    30.2656,
#    200,
#    2018,
#    None,
#    ''],
#   ['austin',
#    'Austin, United States - MetroBike',
#    1,
#    -97.7439,
#    30.2734,
#    399,
#    2013,
#    None,
#    ''],
#   ['austin_ofo',
#    'Austin, United States - ofo',
#    3,
#    -97.7412,
#    30.2626,
#    500,
#    2018,
#    2018,
#    ''],
#   ['austin_pace',
#    'Austin, United States - Pace',
#    3,
#    -97.7368,
#    30.2798,
#    None,
#    2018,
#    2019,
#    ''],
#   ['austin_spin',
#    'Austin, United States - Spin',
#    3,
#    -97.7478,
#    30.267,
#    50,
#    2017,
#    2017,
#    ''],
#   ['austin_veoride',
#    'Austin, United States - VeoRide',
#    1,
#    -97.7332,
#    30.2654,
#    50,
#    2019,
#    None,
#    ''],
#   ['vichyandcusset',
#    'Auvergne Province, France - VIVu00c9LO',
#    1,
#    3.42976,
#    46.1267,
#    47,
#    2018,
#    None,
#    'Vichy, Cusset, Clermont-Ferrand, Issoire, Ennezat, Chu00e2tel-Guyon'],
#   ['aveiro',
#    'Aveiro, Portugal - BUGA 2',
#    1,
#    -8.6526,
#    40.6409,
#    204,
#    2021,
#    None,
#    ''],
#   ['avenches',
#    'Avenches, Switzerland - Publibike',
#    3,
#    7.04155,
#    46.8802,
#    9,
#    2011,
#    2018,
#    ''],
#   ['aventura',
#    'Aventura, United States - Aventura B-cycle',
#    1,
#    -80.1377,
#    25.9554,
#    43,
#    2016,
#    None,
#    ''],
#   ['aversa',
#    'Aversa, Italy - BicinCittu00e0',
#    3,
#    14.2115,
#    40.9731,
#    30,
#    2011,
#    2018,
#    ''],
#   ['avignon',
#    'Avignon, France - Velopop',
#    1,
#    4.80635,
#    43.9487,
#    154,
#    2009,
#    None,
#    ''],
#   ['avilesycastrillon',
#    'Avilu00e9s y Castrillu00f3n, Spain - enbici',
#    1,
#    -5.92097,
#    43.5571,
#    91,
#    2007,
#    None,
#    ''],
#   ['avon',
#    'Avon, United States - Avon Bike Share',
#    3,
#    -106.521,
#    39.6332,
#    25,
#    2017,
#    2020,
#    ''],
#   ['ayianapa',
#    'Ayia Napa, Cyprus - nextbike',
#    1,
#    33.9969,
#    34.9904,
#    105,
#    2021,
#    None,
#    'Ayia Napa and Famagusta'],
#   ['azuquecadehenares',
#    'Azuqueca de Henares, Spain - Biciudad',
#    3,
#    -3.26822,
#    40.5657,
#    50,
#    2009,
#    2014,
#    'Guadalajara'],
#   ['baddeutschaltenburg',
#    'Bad Deutsch Altenburg, Austria - nextbike Niederu00f6sterreich',
#    1,
#    16.9086,
#    48.1329,
#    22,
#    2010,
#    None,
#    'Ru00f6merland'],
#   ['badoeynhausen',
#    'Bad Oeynhausen, Germany - Oeynrad',
#    1,
#    8.79936,
#    52.2047,
#    68,
#    2020,
#    None,
#    ''],
#   ['badajoz',
#    'Badajoz, Spain - BiBa',
#    1,
#    -6.97083,
#    38.8857,
#    99,
#    2009,
#    None,
#    ''],
#   ['baden',
#    'Baden-Baden, Germany - KVV.nextbike',
#    1,
#    8.2496,
#    48.8266,
#    95,
#    2019,
#    None,
#    'Baden-Baden, Rastatt, Gaggenau'],
#   ['baeza', 'Baeza, Spain - ENbici', 3, -3.46928, 37.9937, 25, 2009, 2014, ''],
#   ['bagsvard',
#    'Bagsvu00e6rd, Denmark - Donkey Republic',
#    3,
#    12.4505,
#    55.7614,
#    15,
#    2017,
#    None,
#    ''],
#   ['bahiablanca',
#    'Bahia Blanca, Argentina - ',
#    2,
#    -62.2499,
#    -38.7139,
#    None,
#    None,
#    None,
#    ''],
#   ['baigorria',
#    'Baigorria, Argentina - ',
#    2,
#    -60.7022,
#    -32.8646,
#    None,
#    None,
#    None,
#    ''],
#   ['baiyin', 'Baiyin, China - ', 2, 104.173, 36.5378, 1800, None, None, ''],
#   ['bakersfield_spin',
#    'Bakersfield, United States - Spin',
#    1,
#    -119.015,
#    35.3716,
#    125,
#    2021,
#    None,
#    ''],
#   ['baku',
#    'Baku, Azerbaijan - nextbike',
#    3,
#    49.8476,
#    40.3812,
#    5,
#    2012,
#    2012,
#    ''],
#   ['balashikhapodolsk',
#    'Balashikha & Podolsk, Russia - Velobike',
#    2,
#    37.9584,
#    55.8001,
#    None,
#    None,
#    None,
#    ''],
#   ['balatonlakedistrict',
#    'Balaton Lake District, Hungary - ',
#    6,
#    18.0011,
#    47.0449,
#    200,
#    None,
#    None,
#    ''],
#   ['balchik',
#    'Balchik, Bulgaria - Black Sea Bike',
#    1,
#    28.1634,
#    43.4242,
#    100,
#    2015,
#    None,
#    ''],
#   ['balestrate',
#    'Balestrate, Italy - BikeGal',
#    1,
#    13.0046,
#    38.0518,
#    27,
#    2016,
#    None,
#    ''],
#   ['balneariocamboriu',
#    'Balneu00e1rio Camboriu00fa, Brazil - ',
#    6,
#    -48.6322,
#    -26.9956,
#    300,
#    None,
#    None,
#    ''],
#   ['balneariocamboriu_gomoov',
#    'Balneu00e1rio Camboriu00fa, Brazil - BC Bike',
#    1,
#    -48.6322,
#    -26.9956,
#    50,
#    2022,
#    None,
#    ''],
#   ['baltimore_bird',
#    'Baltimore, United States - Bird',
#    3,
#    -76.5664,
#    39.3019,
#    173,
#    2022,
#    2023,
#    ''],
#   ['baltimore',
#    'Baltimore, United States - Bmore Bikeshare',
#    3,
#    -76.61,
#    39.2909,
#    64,
#    2016,
#    2018,
#    ''],
#   ['baltimore_jump',
#    'Baltimore, United States - Jump',
#    3,
#    -76.5905,
#    39.2863,
#    708,
#    2019,
#    2022,
#    ''],
#   ['baltimore_lime',
#    'Baltimore, United States - Lime',
#    3,
#    -76.6299,
#    39.2901,
#    100,
#    2018,
#    2019,
#    ''],
#   ['baltimore_spin',
#    'Baltimore, United States - Spin',
#    1,
#    -76.6185,
#    39.3127,
#    153,
#    2022,
#    None,
#    ''],
#   ['balzers',
#    'Balzers, Liechtenstein - FreeVeloPoint',
#    3,
#    9.50545,
#    47.0656,
#    10,
#    2018,
#    2021,
#    ''],
#   ['bandarbarunilai',
#    'Bandar Baru Nilai, Malaysia - Anywheel',
#    1,
#    101.782,
#    2.8442,
#    None,
#    2020,
#    None,
#    ''],
#   ['bandholm_donkey',
#    'Bandholm, Denmark - Donkey Republic',
#    1,
#    11.4823,
#    54.8342,
#    None,
#    None,
#    None,
#    ''],
#   ['bandung_bikebandung',
#    'Bandung, Indonesia - Bike Bandung',
#    3,
#    107.614,
#    -6.89294,
#    90,
#    2012,
#    2016,
#    ''],
#   ['bandung',
#    'Bandung, Indonesia - Boseh (Bikes On Street Everyone Happy)',
#    1,
#    107.602,
#    -6.91509,
#    350,
#    2017,
#    None,
#    ''],
#   ['bandung_bukabike',
#    'Bandung, Indonesia - BukaBike',
#    1,
#    107.61,
#    -6.89067,
#    None,
#    2018,
#    None,
#    ''],
#   ['bangkok_mobike',
#    'Bangkok, Thailand - Mobike',
#    3,
#    100.574,
#    13.8527,
#    200,
#    2017,
#    2019,
#    ''],
#   ['bangkok_obike',
#    'Bangkok, Thailand - oBike',
#    3,
#    100.562,
#    13.7512,
#    1000,
#    2017,
#    2018,
#    ''],
#   ['bangkok_ofo',
#    'Bangkok, Thailand - ofo',
#    3,
#    100.491,
#    13.7565,
#    546,
#    2017,
#    2019,
#    ''],
#   ['bangkok_punpun',
#    'Bangkok, Thailand - Pun Pun',
#    1,
#    100.53,
#    13.7332,
#    500,
#    2012,
#    None,
#    ''],
#   ['banjaluka',
#    'Banja Luka, Bosnia and Herzegovina - BL-Bike',
#    1,
#    17.1919,
#    44.7706,
#    30,
#    2018,
#    None,
#    ''],
#   ['baoding_didi',
#    'Baoding, China - DiDi Qingju',
#    1,
#    115.474,
#    38.8837,
#    5000,
#    None,
#    None,
#    ''],
#   ['baoding_hellobike',
#    'Baoding, China - Hellobike',
#    1,
#    115.489,
#    38.8296,
#    5000,
#    None,
#    None,
#    ''],
#   ['baoding',
#    'Baoding, China - Meituan Bike',
#    3,
#    115.588,
#    38.8363,
#    5000,
#    2017,
#    2020,
#    ''],
#   ['baofengcounty',
#    'Baofeng County, China - Baofeng County Public Bicycle System',
#    1,
#    113.057,
#    33.8671,
#    1000,
#    2017,
#    None,
#    ''],
#   ['baoji_baojicity',
#    'Baoji, China - Baoji City Public Bicycle',
#    1,
#    107.233,
#    34.3678,
#    2000,
#    2013,
#    None,
#    ''],
#   ['baoji_mobike',
#    'Baoji, China - Meituan Bike',
#    3,
#    107.159,
#    34.3905,
#    None,
#    2017,
#    2020,
#    ''],
#   ['baoshan',
#    'Baoshan, China - Meituan Bike',
#    3,
#    99.1688,
#    25.117,
#    None,
#    None,
#    2020,
#    ''],
#   ['baranavichy',
#    'Baranavichy, Belarus - u041au043eu043bu043eu0431u0430u0439u043a (KoloBike)',
#    1,
#    26.021,
#    53.13,
#    50,
#    2020,
#    None,
#    ''],
#   ['baranovichi',
#    'Baranovichi, Belarus - ',
#    2,
#    26.0197,
#    53.1334,
#    None,
#    None,
#    None,
#    ''],
#   ['barcellonapozzodigotto',
#    'Barcellona Pozzo di Gotto, Italy - Bicincittu00e0',
#    1,
#    15.2121,
#    38.1568,
#    50,
#    2013,
#    None,
#    ''],
#   ['barcelona_mobike',
#    'Barcelona and Hospitalet de Llobregat, Spain - RideMovi',
#    1,
#    2.1123,
#    41.3814,
#    832,
#    2018,
#    None,
#    ''],
#   ['barcelona_metro',
#    'Barcelona Metropolitan Area, Spain - AMBici',
#    1,
#    2.151,
#    41.4252,
#    1287,
#    2023,
#    None,
#    'Cornellu00e0, Esplugues, Sant Boi, El Prat, Sant Joan Despu00ed, Sant Just Desvern and Castelldefels'],
#   ['barcelona',
#    'Barcelona, Spain - Bicing',
#    1,
#    2.17714,
#    41.3772,
#    5000,
#    2007,
#    None,
#    ''],
#   ['barcelona_bolt',
#    'Barcelona, Spain - Bolt',
#    1,
#    2.1857,
#    41.4039,
#    396,
#    2020,
#    None,
#    ''],
#   ['barcelona_donkeyre',
#    'Barcelona, Spain - Donkey Republic',
#    1,
#    2.16103,
#    41.3898,
#    858,
#    2016,
#    None,
#    ''],
#   ['barcelona_scoot',
#    'Barcelona, Spain - Scoot',
#    1,
#    2.2242,
#    41.3863,
#    1000,
#    2018,
#    None,
#    ''],
#   ['bari_vaimoo',
#    'Bari, Italy - Bari Bike Sharing',
#    1,
#    16.8632,
#    41.1097,
#    200,
#    2023,
#    None,
#    ''],
#   ['bari',
#    'Bari, Italy - BarinBici',
#    3,
#    16.8697,
#    41.1276,
#    200,
#    2007,
#    2016,
#    ''],
#   ['barkarby',
#    'Barkarby, Sweden - Nobina',
#    1,
#    17.865,
#    59.4033,
#    None,
#    2020,
#    None,
#    ''],
#   ['barletta',
#    'Barletta, Italy - Bicincittu00e0',
#    3,
#    16.2841,
#    41.3198,
#    25,
#    2011,
#    2016,
#    ''],
#   ['picarras',
#    'Barra Velha, Penha and Piu00e7arras, Brazil - ',
#    1,
#    -48.6621,
#    -26.7747,
#    100,
#    2022,
#    None,
#    'Barra Velha, Penha and Piu00e7arras'],
#   ['barranquilla',
#    'Barranquilla, Colombia - SIBAQ',
#    2,
#    -74.7836,
#    10.9887,
#    None,
#    2016,
#    None,
#    ''],
#   ['barreiro',
#    'Barreiro, Portugal - TCB Mobilidade Colectiva',
#    5,
#    -9.07354,
#    38.66,
#    10,
#    2017,
#    None,
#    ''],
#   ['basel',
#    'Basel, Switzerland - Pick-e-Bike',
#    1,
#    7.5927,
#    47.5608,
#    350,
#    2018,
#    None,
#    ''],
#   ['basel_publibike',
#    'Basel, Switzerland - Publibike',
#    3,
#    7.59353,
#    47.5468,
#    6,
#    2011,
#    2018,
#    ''],
#   ['bassanodelgrappa',
#    'Bassano del Grappa, Italy - BicinCittu00e0',
#    3,
#    11.7341,
#    45.7644,
#    12,
#    2009,
#    2018,
#    ''],
#   ['bastad',
#    'Bu00e5stad, Sweden - Donkey Republic',
#    4,
#    12.848,
#    56.4272,
#    41,
#    2019,
#    None,
#    ''],
#   ['bastia_ira',
#    'Bastia, France - IRA de Bastia',
#    1,
#    9.45183,
#    42.699,
#    5,
#    2021,
#    None,
#    ''],
#   ['bath',
#    'Bath, United Kingdom - Bike in Bath',
#    3,
#    -2.36052,
#    51.3807,
#    30,
#    2011,
#    2013,
#    ''],
#   ['bath_nextbike',
#    'Bath, United Kingdom - Nextbike',
#    3,
#    -2.35708,
#    51.379,
#    67,
#    2014,
#    2019,
#    ''],
#   ['bath_westbike',
#    'Bath, United Kingdom - WESTbike',
#    1,
#    -2.3388,
#    51.3869,
#    294,
#    2023,
#    None,
#    ''],
#   ['bathurst',
#    'Bathurst, Australia - The Boomerangs Bike',
#    3,
#    149.579,
#    -33.4187,
#    8,
#    2016,
#    2018,
#    ''],
#   ['batonrouge',
#    'Baton Rouge, United States - Gotcha',
#    1,
#    -91.1858,
#    30.4466,
#    500,
#    2019,
#    None,
#    ''],
#   ['battlecreek',
#    'Battle Creek, United States - BCycle',
#    4,
#    -85.1808,
#    42.325,
#    19,
#    2013,
#    None,
#    ''],
#   ['batumi',
#    'Batumi, Georgia - Batumvelo',
#    1,
#    41.6462,
#    41.6549,
#    70,
#    2011,
#    None,
#    ''],
#   ['bayannur',
#    'Bayannur, China - Meituan Bike',
#    3,
#    107.385,
#    40.7368,
#    None,
#    2011,
#    2020,
#    ''],
#   ['bayonne_cyclocom',
#    'Bayonne, France - Cyclocom',
#    1,
#    -1.48315,
#    43.4938,
#    100,
#    2009,
#    None,
#    ''],
#   ['bayonne_jersey',
#    'Bayonne, United States - Jersey Bike Share',
#    3,
#    -74.1083,
#    40.6721,
#    None,
#    2018,
#    2020,
#    ''],
#   ['bedford',
#    'Bedford, United Kingdom - ',
#    6,
#    -0.478993,
#    52.1371,
#    None,
#    2018,
#    2018,
#    ''],
#   ['bedford_lime',
#    'Bedford, United States - Lime',
#    3,
#    -71.2738,
#    42.4903,
#    240,
#    2018,
#    2019,
#    ''],
#   ['beian',
#    "Bei'an, China - Bei'an Public Bicycle",
#    4,
#    126.509,
#    48.2461,
#    2000,
#    2014,
#    None,
#    ''],
#   ['beihai',
#    'Beihai, China - Meituan Bike',
#    3,
#    109.1,
#    21.4722,
#    None,
#    2017,
#    2020,
#    ''],
#   ['beijing_beijingrentalcompany',
#    'Beijing, China - Beijing Bicycle Rental Company',
#    6,
#    116.378,
#    39.9013,
#    None,
#    2011,
#    None,
#    ''],
#   ['beijing_bluegogo',
#    'Beijing, China - Bluegogo',
#    3,
#    116.38,
#    39.9519,
#    5000,
#    2017,
#    2018,
#    ''],
#   ['beijing_changping',
#    'Beijing, China - Changping Public Bicycle Service',
#    3,
#    116.244,
#    40.2051,
#    616,
#    2015,
#    2021,
#    'Changping, Huilongguan and Tiantongyuan Districts'],
#   ['beijing_conveniencebee',
#    'Beijing, China - Convenience Bee Bike',
#    3,
#    116.38,
#    40,
#    5000,
#    2019,
#    None,
#    ''],
#   ['beijing_daxing',
#    'Beijing, China - Daxing Public Bicycle System',
#    3,
#    116.338,
#    39.723,
#    5000,
#    2012,
#    2022,
#    'Daxing District'],
#   ['beijing_didi',
#    'Beijing, China - DiDi Qingju',
#    1,
#    116.346,
#    39.9149,
#    5000,
#    2019,
#    None,
#    ''],
#   ['beijing_fangshan',
#    'Beijing, China - Fangshan Public Bicycle',
#    3,
#    116.154,
#    39.7369,
#    5000,
#    2015,
#    None,
#    'Fangshan District'],
#   ['beijing_yizhuangchen_hello',
#    'Beijing, China - Hellobike',
#    1,
#    116.402,
#    39.8665,
#    5000,
#    2021,
#    None,
#    'Yizhuang District'],
#   ['beijing_mobike',
#    'Beijing, China - Meituan Bike',
#    1,
#    116.409,
#    39.9488,
#    5000,
#    2016,
#    2018,
#    ''],
#   ['beijing_miyun',
#    'Beijing, China - Miyun',
#    1,
#    116.852,
#    40.3847,
#    3080,
#    2016,
#    None,
#    'Miyun District'],
#   ['beijing_municipalpilot',
#    'Beijing, China - Municipal Pilot',
#    3,
#    116.446,
#    39.9134,
#    None,
#    2010,
#    2011,
#    'Chaoyang District'],
#   ['beijing_ofo',
#    'Beijing, China - ofo',
#    3,
#    116.308,
#    39.9863,
#    5000,
#    2014,
#    2018,
#    ''],
#   ['beijing_municipal',
#    'Beijing, China - Public Bicycle in Beijing',
#    3,
#    116.435,
#    39.9129,
#    5000,
#    2012,
#    2021,
#    ''],
#   ['beijing_sevencolorbike',
#    'Beijing, China - Seven Color Bike',
#    3,
#    116.479,
#    39.9963,
#    1000,
#    2017,
#    None,
#    ''],
#   ['beijing_shunyi',
#    'Beijing, China - Shunyi Public Bicycle',
#    3,
#    116.658,
#    40.118,
#    1600,
#    2014,
#    None,
#    'Shunyi District'],
#   ['beijing_taihu',
#    'Beijing, China - Taihu Public Bicycle',
#    3,
#    116.651,
#    39.8323,
#    1000,
#    2016,
#    2021,
#    'Taihuzhen District and Tongzhou'],
#   ['beijing_tongzhou',
#    'Beijing, China - Tongzhou Public Bicycle',
#    3,
#    116.666,
#    39.8896,
#    5000,
#    2013,
#    2021,
#    'Tongzhou District'],
#   ['beijing_yizhuangchen',
#    'Beijing, China - Yizhuangchen Public Bicycle',
#    3,
#    116.482,
#    39.801,
#    1000,
#    2011,
#    None,
#    'Yizhuang District'],
#   ['beijing_zhixiang',
#    'Beijing, China - Zhixiang Bicycle',
#    3,
#    116.31,
#    39.99,
#    1000,
#    2019,
#    2019,
#    ''],
#   ['beilun_beilun',
#    'Beilun, China - Beilun Public Bicycle',
#    1,
#    121.85,
#    29.9049,
#    2350,
#    2014,
#    None,
#    ''],
#   ['beilun_mobike',
#    'Beilun, China - Meituan Bike',
#    3,
#    121.848,
#    29.8611,
#    None,
#    2017,
#    2020,
#    ''],
#   ['beirut',
#    'Beirut, Lebanon - Bike 4 All',
#    3,
#    35.5067,
#    33.8979,
#    5,
#    2017,
#    2020,
#    ''],
#   ['beizhen',
#    'Beizhen, China - Meituan Bike',
#    3,
#    121.797,
#    41.5962,
#    None,
#    2017,
#    2020,
#    ''],
#   ['belagavi', 'Belagavi, India - ', 1, 74.5129, 15.8746, 300, 2022, None, ''],
#   ['belayatserkov',
#    'Belaya Tserkov, Ukraine - nextbike',
#    6,
#    30.1243,
#    49.8005,
#    None,
#    2019,
#    None,
#    ''],
#   ['belem',
#    'Belu00e9m, Brazil - Bike Belu00e9m',
#    3,
#    -48.5007,
#    -1.45811,
#    110,
#    2016,
#    2020,
#    ''],
#   ['belendeescobar',
#    'Belu00e9n de Escobar, Argentina - Las Bicis',
#    1,
#    -58.7826,
#    -34.3558,
#    200,
#    2019,
#    None,
#    ''],
#   ['belfast',
#    'Belfast, United Kingdom - Just Eat Belfast Bikes',
#    1,
#    -5.92292,
#    54.5969,
#    406,
#    2015,
#    None,
#    ''],
#   ['belfort',
#    'Belfort, France - Optymo',
#    1,
#    6.86302,
#    47.6402,
#    274,
#    2013,
#    None,
#    ''],
#   ['belgrade',
#    'Belgrade, Serbia - ',
#    2,
#    20.459,
#    44.8253,
#    1000,
#    None,
#    None,
#    ''],
#   ['bellevue',
#    'Bellevue, United States - Lime',
#    3,
#    -122.202,
#    47.6136,
#    50,
#    2018,
#    2019,
#    ''],
#   ['bellflower',
#    'Bellflower, United States - ofo',
#    3,
#    -118.125,
#    33.8824,
#    200,
#    2017,
#    2018,
#    ''],
#   ['belmont_massachusetts',
#    'Belmont, United States - Lime',
#    3,
#    -71.1758,
#    42.3948,
#    50,
#    2018,
#    2019,
#    ''],
#   ['belmont_california',
#    'Belmont, United States - Lime',
#    3,
#    -122.276,
#    37.5194,
#    None,
#    None,
#    None,
#    ''],
#   ['belohorizonte',
#    'Belo Horizonte, Brazil - Bike BH - Itau00fa',
#    3,
#    -43.9437,
#    -19.9213,
#    400,
#    2014,
#    2019,
#    ''],
#   ['belohorizonte_bikebh',
#    'Belo Horizonte, Brazil - Bike BH - Unimed',
#    1,
#    -43.9545,
#    -19.8574,
#    200,
#    2019,
#    None,
#    'Pampulha'],
#   ['bikebh',
#    'Belo Horizonte, Brazil - Tembici',
#    1,
#    -43.9292,
#    -19.9192,
#    100,
#    2023,
#    None,
#    'Belo Horizonte'],
#   ['belohorizonte_yellow',
#    'Belo Horizonte, Brazil - Yellow',
#    3,
#    -43.9387,
#    -19.9298,
#    500,
#    2019,
#    2020,
#    ''],
#   ['bemidji',
#    'Bemidji, United States - Nice ride Minnesota',
#    3,
#    -94.8817,
#    47.4826,
#    None,
#    2014,
#    2018,
#    ''],
#   ['bemowo',
#    'Bemowo, Poland - Bemowo Bike',
#    3,
#    20.9118,
#    52.2446,
#    25,
#    2012,
#    2020,
#    ''],
#   ['bend_bird',
#    'Bend, United States - Bird',
#    1,
#    -121.312,
#    44.0598,
#    250,
#    2022,
#    None,
#    ''],
#   ['bend',
#    'Bend, United States - OSU Cascades',
#    3,
#    -121.312,
#    44.0598,
#    55,
#    2016,
#    2020,
#    ''],
#   ['benesov',
#    'Beneu0161ov, Czech Republic - nextbike',
#    1,
#    14.688,
#    49.783,
#    49,
#    2023,
#    None,
#    ''],
#   ['benevento',
#    'Benevento, Italy - BeneBike',
#    3,
#    14.7824,
#    41.1302,
#    30,
#    2014,
#    2021,
#    ''],
#   ['bengaluru',
#    'Bengaluru, India - ',
#    2,
#    77.5705,
#    12.9778,
#    None,
#    None,
#    None,
#    ''],
#   ['bengaluru_nammacycles',
#    'Bengaluru, India - Namma Cycles',
#    2,
#    77.5672,
#    13.0226,
#    None,
#    None,
#    None,
#    ''],
#   ['bengaluru_pedl',
#    'Bengaluru, India - Pedl',
#    1,
#    77.5946,
#    12.9699,
#    500,
#    2018,
#    None,
#    ''],
#   ['bengaluru_yulu',
#    'Bengaluru, India - Yulu',
#    1,
#    77.6254,
#    12.9765,
#    250,
#    2019,
#    None,
#    ''],
#   ['bengaluru_namaste',
#    'Bengaluru, India - Yulu',
#    1,
#    77.678,
#    12.9233,
#    3000,
#    2018,
#    None,
#    'Namaste'],
#   ['bengaluru_electroniccity',
#    'Bengaluru, India - Yulu',
#    1,
#    77.6707,
#    12.8466,
#    400,
#    2018,
#    None,
#    'Electronic City'],
#   ['bengbu_hellobike',
#    'Bengbu, China - HelloBike',
#    1,
#    117.354,
#    32.9382,
#    5000,
#    2018,
#    None,
#    ''],
#   ['benidorm',
#    'Benidorm, Spain - Bicidorm',
#    3,
#    -0.127544,
#    38.5388,
#    70,
#    2011,
#    2020,
#    ''],
#   ['bentonville',
#    'Bentonville, United States - TIER',
#    1,
#    -94.2189,
#    36.3764,
#    27,
#    2023,
#    None,
#    ''],
#   ['benxi',
#    'Benxi, China - Meituan Bike',
#    3,
#    123.684,
#    41.4896,
#    None,
#    2017,
#    2020,
#    ''],
#   ['bergamo_bicincitta',
#    'Bergamo, Italy - La BiGi',
#    3,
#    9.67089,
#    45.6962,
#    114,
#    2009,
#    2021,
#    ''],
#   ['bergamo',
#    'Bergamo, Italy - La BiGi 2022',
#    1,
#    9.6457,
#    45.6662,
#    392,
#    2022,
#    None,
#    ''],
#   ['bergamo_mobike',
#    'Bergamo, Italy - Movi by Mobike',
#    3,
#    9.7076,
#    45.6612,
#    500,
#    2017,
#    2021,
#    ''],
#   ['bergenopzoom',
#    'Bergen op Zoom, Netherlands - Bravo',
#    1,
#    4.2888,
#    51.4964,
#    100,
#    2020,
#    None,
#    ''],
#   ['bergen', 'Bergen, Norway - Bolt', 2, 5.3271, 60.4034, 200, None, None, ''],
#   ['bergen_bysykkel',
#    'Bergen, Norway - Bysykkel',
#    1,
#    5.3379,
#    60.3935,
#    750,
#    2017,
#    None,
#    ''],
#   ['bergen_bysykler',
#    'Bergen, Norway - Bysykler',
#    3,
#    5.32013,
#    60.3888,
#    None,
#    2002,
#    2017,
#    ''],
#   ['bergisch',
#    'Bergisch, Germany - Bergisches e-Bike',
#    1,
#    7.16,
#    51.02,
#    95,
#    2020,
#    None,
#    ''],
#   ['berlin_byke',
#    'Berlin, Germany - BYKE',
#    3,
#    13.3582,
#    52.5007,
#    300,
#    2017,
#    2020,
#    ''],
#   ['berlin_lidlbike',
#    'Berlin, Germany - Call a Bike',
#    1,
#    13.4526,
#    52.517,
#    1516,
#    2002,
#    None,
#    ''],
#   ['berlin_donkeyre',
#    'Berlin, Germany - Donkey Republic',
#    1,
#    13.4197,
#    52.5007,
#    369,
#    2017,
#    None,
#    ''],
#   ['berlin_flotte',
#    'Berlin, Germany - fLotte',
#    1,
#    13.4718,
#    52.4877,
#    120,
#    2017,
#    None,
#    ''],
#   ['berlin_jump',
#    'Berlin, Germany - Jump',
#    3,
#    13.3823,
#    52.5156,
#    5000,
#    2019,
#    2020,
#    ''],
#   ['berlin_limebike',
#    'Berlin, Germany - Jump by Lime',
#    1,
#    13.3554,
#    52.5325,
#    1000,
#    2018,
#    None,
#    ''],
#   ['berlin_mobike',
#    'Berlin, Germany - Mobike',
#    3,
#    13.41,
#    52.5184,
#    5000,
#    2017,
#    2020,
#    ''],
#   ['berlin_deezernextbike',
#    'Berlin, Germany - Nextbike',
#    1,
#    13.4025,
#    52.5514,
#    5000,
#    2013,
#    None,
#    'Berlin, Buch'],
#   ['berlin_obike',
#    'Berlin, Germany - oBike',
#    3,
#    13.3948,
#    52.5321,
#    700,
#    2017,
#    2018,
#    ''],
#   ['berlin_ofo',
#    'Berlin, Germany - ofo',
#    3,
#    13.4342,
#    52.5399,
#    2000,
#    2018,
#    2019,
#    ''],
#   ['berlin',
#    'Berlin, Germany - TIER',
#    1,
#    13.3778,
#    52.4923,
#    3075,
#    2022,
#    None,
#    ''],
#   ['berlin_voi',
#    'Berlin, Germany - Voi',
#    1,
#    13.376,
#    52.491,
#    100,
#    2022,
#    None,
#    ''],
#   ['bern_publibike',
#    'Bern, Switzerland - Publibike',
#    1,
#    7.44212,
#    46.9554,
#    1750,
#    2011,
#    None,
#    ''],
#   ['bern_smide',
#    'Bern, Switzerland - smide',
#    3,
#    7.44847,
#    46.9485,
#    50,
#    2018,
#    2020,
#    ''],
#   ['beroun',
#    'Beroun, Czech Republic - Nextbike',
#    1,
#    14.0594,
#    49.9645,
#    133,
#    2020,
#    None,
#    ''],
#   ['bertioga',
#    'Bertioga, Brazil - Rivibike',
#    1,
#    -46.0231,
#    -23.797,
#    56,
#    2012,
#    None,
#    ''],
#   ['besancon',
#    'Besanu00e7on, France - Vu00e9loCitu00e9',
#    1,
#    6.03115,
#    47.2452,
#    201,
#    2007,
#    None,
#    ''],
#   ['beverlyhills',
#    'Beverly Hills, United States - Beverly Hills Bike Share',
#    3,
#    -118.405,
#    34.0717,
#    43,
#    2016,
#    2021,
#    ''],
#   ['bezau',
#    'Bezau-Schoppernau Area, Austria - nextbike',
#    3,
#    9.95224,
#    47.3456,
#    100,
#    2009,
#    2020,
#    ''],
#   ['bhopal',
#    'Bhopal, India - Chartered Bike',
#    1,
#    77.4251,
#    23.2498,
#    397,
#    2017,
#    None,
#    ''],
#   ['bhubaneswar_mobike',
#    'Bhubaneswar, India - Mobike',
#    6,
#    85.8345,
#    20.2818,
#    None,
#    None,
#    None,
#    ''],
#   ['bhubaneswar_mocycles',
#    'Bhubaneswar, India - MoCycles',
#    1,
#    85.8525,
#    20.2917,
#    300,
#    2018,
#    None,
#    ''],
#   ['bialystok',
#    'Bialystok, Poland - BikeR',
#    1,
#    23.1657,
#    53.133,
#    641,
#    2014,
#    None,
#    ''],
#   ['biarritz',
#    'Biarritz, France - Le Vu00e9lo Libre-Service',
#    3,
#    -1.56212,
#    43.4819,
#    15,
#    2018,
#    2019,
#    ''],
#   ['biarritz_kaboo',
#    'Biarritz, France - Vu00e9libleu',
#    1,
#    -1.5267,
#    43.4721,
#    120,
#    2019,
#    None,
#    'Bayonne, Hendaye, Bidart and Saint Jean-de-Luz'],
#   ['biddeford',
#    'Biddeford, United States - Bike Share',
#    3,
#    -70.3901,
#    43.4569,
#    30,
#    2016,
#    2020,
#    ''],
#   ['biel',
#    'Biel, Switzerland - Velospot Switzerland',
#    1,
#    7.24493,
#    47.133,
#    250,
#    2010,
#    None,
#    'Bienne and Neuchu00e2tel'],
#   ['bielefeld',
#    'Bielefeld, Germany - meinSiggi Bielefeld',
#    1,
#    8.535,
#    52.0238,
#    632,
#    2009,
#    None,
#    ''],
#   ['biella',
#    'Biella, Italy - BicinCittu00e0',
#    3,
#    8.06465,
#    45.5587,
#    6,
#    2008,
#    2020,
#    ''],
#   ['bielsko',
#    'Bielsko-Biala, Poland - BBbike',
#    3,
#    19.041,
#    49.8198,
#    149,
#    2014,
#    2022,
#    ''],
#   ['bilbao',
#    'Bilbao, Spain - Bilbaobizi',
#    1,
#    -2.9342,
#    43.2676,
#    629,
#    2018,
#    None,
#    ''],
#   ['bilbao_bilbonbizi',
#    'Bilbao, Spain - Bilbon Bizi',
#    3,
#    -2.9331,
#    43.2528,
#    260,
#    2011,
#    2018,
#    ''],
#   ['biloxi',
#    'Biloxi, United States - Bike Share',
#    3,
#    -88.9007,
#    30.3949,
#    10,
#    2017,
#    2020,
#    ''],
#   ['binghamton_uni',
#    'Binghamton, United States - Binghamton University',
#    1,
#    -75.9692,
#    42.089,
#    30,
#    2023,
#    None,
#    'Binghamton University'],
#   ['binzhou',
#    'Binzhou, China - Binzhou Public Bicycles',
#    1,
#    117.977,
#    37.3843,
#    500,
#    2013,
#    None,
#    ''],
#   ['birmingham',
#    'Birmingham, United Kingdom - ',
#    6,
#    -1.9866,
#    52.4812,
#    5000,
#    2019,
#    None,
#    ''],
#   ['birmingham_zyp',
#    'Birmingham, United States - Zyp',
#    3,
#    -86.8126,
#    33.5242,
#    231,
#    2015,
#    2019,
#    ''],
#   ['bishkek',
#    'Bishkek, Kyrgyzstan - ',
#    1,
#    74.5741,
#    42.8758,
#    490,
#    2022,
#    None,
#    ''],
#   ['bismarck',
#    'Bismarck, United States - BisParks BCycle',
#    1,
#    -100.786,
#    46.8079,
#    None,
#    2022,
#    None,
#    ''],
#   ['bistria',
#    'Bistriu021ba, Romania - BIke Sharing',
#    2,
#    24.4938,
#    47.131,
#    175,
#    None,
#    None,
#    ''],
#   ['bilbao_metropolis',
#    'Bizkaia, Spain - Bizkaibizi',
#    1,
#    -2.97896,
#    43.3104,
#    650,
#    2023,
#    None,
#    'Barakaldo, Berango, Bilbao, Erandio, Getxo, Leioa, Portugalete, Santurtzi, Sestao'],
#   ['blackpool',
#    'Blackpool, United Kingdom - Cycle Blackpool',
#    3,
#    -3.05343,
#    53.8142,
#    186,
#    2009,
#    2015,
#    ''],
#   ['blacksburg',
#    'Blacksburg, United States - Roam New River Valley',
#    1,
#    -80.4148,
#    37.2269,
#    75,
#    2018,
#    None,
#    ''],
#   ['blagoveshchensk',
#    'Blagoveshchensk, Russia - ',
#    1,
#    127.539,
#    50.27,
#    250,
#    2015,
#    None,
#    ''],
#   ['bloomington',
#    'Bloomington, United States - Pace',
#    3,
#    -86.5235,
#    39.1672,
#    150,
#    2018,
#    2019,
#    ''],
#   ['blueash',
#    'Blue Ash, United States - Bike Share',
#    3,
#    -84.3774,
#    39.2324,
#    50,
#    2018,
#    2020,
#    ''],
#   ['blumenau',
#    'Blumenau, Brazil - Samba Blumenau',
#    3,
#    -49.0656,
#    -26.9178,
#    60,
#    2009,
#    2011,
#    ''],
#   ['boai',
#    "Bo'ai, China - Boai Public Bicycle",
#    1,
#    113.068,
#    35.1698,
#    100,
#    2017,
#    None,
#    ''],
#   ['bobcaygeonfenelonfalls',
#    'Bobcaygeon & Fenelon Falls, Canada - Bike Share',
#    1,
#    -78.5495,
#    44.5428,
#    20,
#    2017,
#    None,
#    ''],
#   ['bogota_bicico',
#    'Bogotu00e1, Colombia - BiciCo',
#    3,
#    -74.0754,
#    4.6429,
#    50,
#    2018,
#    2019,
#    ''],
#   ['bogota_muvo',
#    'Bogotu00e1, Colombia - Muvo',
#    3,
#    -74.0473,
#    4.67271,
#    150,
#    2017,
#    2021,
#    ''],
#   ['bogota',
#    'Bogotu00e1, Colombia - Tembici',
#    1,
#    -74.0973,
#    4.6435,
#    3300,
#    2022,
#    None,
#    ''],
#   ['boise',
#    'Boise, United States - Boise Green Bike',
#    3,
#    -116.208,
#    43.6169,
#    127,
#    2015,
#    2020,
#    ''],
#   ['boise_lime',
#    'Boise, United States - Lime',
#    6,
#    -116.236,
#    43.612,
#    None,
#    None,
#    None,
#    ''],
#   ['boise_drop',
#    'Boise, United States - Vall-eBike',
#    3,
#    -116.206,
#    43.5973,
#    50,
#    None,
#    2022,
#    ''],
#   ['boleslawiec',
#    'Bolesu0142awiec, Poland - Brom',
#    3,
#    15.5547,
#    51.2798,
#    50,
#    2018,
#    2023,
#    ''],
#   ['bologna',
#    'Bologna, Italy - Movi by Mobike',
#    1,
#    11.3425,
#    44.5035,
#    2300,
#    2018,
#    None,
#    ''],
#   ['bolzano',
#    'Bolzano, Italy - Bici Bolzano',
#    1,
#    11.3065,
#    46.4879,
#    50,
#    2019,
#    None,
#    'Including rural areas surrounding Bolzano'],
#   ['bonn',
#    'Bonn, Germany - Nextbike',
#    1,
#    7.09562,
#    50.7386,
#    903,
#    2018,
#    None,
#    ''],
#   ['bordeaux_bird',
#    'Bordeaux, France - Bird',
#    1,
#    -0.5816,
#    44.8175,
#    581,
#    2023,
#    None,
#    ''],
# ...
#    None,
#    ''],
#   ['downey',
#    'Downey, United States - Downey Bike Share',
#    3,
#    -118.14,
#    33.9365,
#    20,
#    2019,
#    2020,
#    ''],
#   ['dragor',
#    'Dragu00f8r, Denmark - Donkey Republic',
#    5,
#    12.6743,
#    55.5912,
#    12,
#    2016,
#    None,
#    ''],
#   ['drammen_bolt',
#    'Drammen, Norway - Bolt',
#    1,
#    10.197,
#    59.7569,
#    180,
#    2022,
#    None,
#    ''],
#   ['drammen',
#    'Drammen, Norway - Drammen Bysykkel',
#    3,
#    10.2145,
#    59.7509,
#    80,
#    2001,
#    2021,
#    ''],
#   ['dravaarea',
#    'Drava Area, Hungary - Green Bicycle Drava',
#    1,
#    18.232,
#    45.8522,
#    70,
#    2015,
#    None,
#    'Harku00e1ny, Ku00e9mesi, Sellye, Vajszlu00f3 and Villu00e1ny'],
#   ['dreieich',
#    'Dreieich, Germany - Byke',
#    3,
#    8.69396,
#    50.0275,
#    100,
#    2017,
#    2018,
#    ''],
#   ['dresden',
#    'Dresden, Germany - MOBIbike',
#    1,
#    13.7302,
#    51.0483,
#    1488,
#    2007,
#    None,
#    ''],
#   ['drni',
#    'Drniu0161, Croatia - Nextbike',
#    1,
#    16.1578,
#    43.859,
#    16,
#    2019,
#    None,
#    ''],
#   ['druento',
#    'Druento, Italy - BicinComune',
#    1,
#    7.57868,
#    45.1316,
#    2,
#    2008,
#    None,
#    ''],
#   ['dubai_byky',
#    'Dubai, United Arab Emirates - BYKY',
#    3,
#    55.2173,
#    25.1751,
#    1335,
#    2013,
#    2019,
#    ''],
#   ['dubai',
#    'Dubai, United Arab Emirates - Careem Bike',
#    1,
#    55.1545,
#    25.0921,
#    1335,
#    2020,
#    None,
#    ''],
#   ['dubai_tier',
#    'Dubai, United Arab Emirates - TIER',
#    1,
#    55.3595,
#    25.2267,
#    85,
#    2022,
#    None,
#    ''],
#   ['dublincounty',
#    'Dublin, Ireland - BleeperBike',
#    1,
#    -6.2419,
#    53.3262,
#    638,
#    2017,
#    None,
#    'f Dublin City, Du00fan Laoghaireu2013Rathdown and Fingal '],
#   ['dublin',
#    'Dublin, Ireland - Just Eat dublinbikes',
#    1,
#    -6.2878,
#    53.331,
#    1456,
#    2009,
#    None,
#    ''],
#   ['dublin_mobymove',
#    'Dublin, Ireland - Moby Move',
#    1,
#    -6.2834,
#    53.3611,
#    443,
#    2020,
#    None,
#    ''],
#   ['dublin_urbo',
#    'Dublin, Ireland - Urbo',
#    6,
#    -6.24782,
#    53.3539,
#    None,
#    None,
#    None,
#    ''],
#   ['dublin_zipp',
#    'Dublin, Ireland - Zipp',
#    1,
#    -6.2129,
#    53.2986,
#    27,
#    2022,
#    None,
#    ''],
#   ['dujiangyan_cozy',
#    'Dujiangyan, China - Cozy',
#    1,
#    103.615,
#    30.9658,
#    1500,
#    2010,
#    None,
#    ''],
#   ['dujiangyan_mobike',
#    'Dujiangyan, China - Meituan Bike',
#    3,
#    103.615,
#    30.9963,
#    1500,
#    2017,
#    2020,
#    ''],
#   ['dumfries',
#    'Dumfries, United Kingdom - Bike2go',
#    3,
#    -3.61253,
#    55.0684,
#    26,
#    2010,
#    2015,
#    ''],
#   ['dundalk', 'Dundalk, Ireland - ', 2, -6.40372, 53.9984, 27, None, None, ''],
#   ['dundee',
#    'Dundee, United Kingdom - Embark Dundee',
#    3,
#    -2.9682,
#    56.4604,
#    170,
#    2020,
#    2022,
#    ''],
#   ['dunhuang',
#    'Dunhuang, China - ',
#    2,
#    94.6637,
#    40.1343,
#    None,
#    None,
#    None,
#    ''],
#   ['dunkirk',
#    "Dunkirk, France - Dk'Vu00e9lo",
#    3,
#    2.37648,
#    51.0355,
#    280,
#    2013,
#    None,
#    ''],
#   ['duqiao',
#    'Duqiao, China - Duqiao Public Bicycle',
#    1,
#    121.493,
#    28.7616,
#    1200,
#    2015,
#    None,
#    ''],
#   ['durban',
#    'Durban, South Africa - ',
#    6,
#    31.0343,
#    -29.8573,
#    None,
#    None,
#    None,
#    ''],
#   ['durham_limebike',
#    'Durham, United States - Lime',
#    3,
#    -78.9244,
#    36.0075,
#    500,
#    2017,
#    2019,
#    ''],
#   ['durham_ofo',
#    'Durham, United States - ofo',
#    3,
#    -78.8987,
#    35.9937,
#    None,
#    2017,
#    2018,
#    ''],
#   ['durham_spin',
#    'Durham, United States - Spin',
#    3,
#    -78.9012,
#    35.9956,
#    300,
#    2017,
#    2019,
#    ''],
#   ['dushanbe',
#    'Dushanbe, Tajikistan - Parastu',
#    1,
#    68.7713,
#    38.5669,
#    100,
#    2020,
#    None,
#    ''],
#   ['dusseldorf',
#    'Du00fcsseldorf, Germany - FordPass-Bike',
#    3,
#    6.78955,
#    51.2247,
#    350,
#    2017,
#    2019,
#    ''],
#   ['dusseldorf_mobike',
#    'Du00fcsseldorf, Germany - Mobike',
#    3,
#    6.77307,
#    51.2299,
#    600,
#    2018,
#    2020,
#    ''],
#   ['dusseldorf_nextbike',
#    'Du00fcsseldorf, Germany - nextbike',
#    1,
#    6.77994,
#    51.2215,
#    1129,
#    2008,
#    None,
#    ''],
#   ['dsseldorf',
#    'Du00fcsseldorf, Germany - TIER',
#    1,
#    6.7874,
#    51.2352,
#    837,
#    2022,
#    None,
#    'Du00fcsseldorf, Meerbusch, Neuss'],
#   ['dusseldorf_voi',
#    'Dusseldorf, Germany - Voi',
#    1,
#    6.7445,
#    51.2377,
#    187,
#    None,
#    None,
#    ''],
#   ['duszniki',
#    'Duszniki-Zdru00f3j, Poland - ',
#    1,
#    16.3921,
#    50.4042,
#    15,
#    2019,
#    None,
#    ''],
#   ['dvrkrlov',
#    'Dvu016fr Kru00e1lovu00e9, Czech Republic - nextbike',
#    1,
#    15.8164,
#    50.4314,
#    50,
#    2022,
#    None,
#    ''],
#   ['eagle_county',
#    'Eagle County, United States - Shift Bikes',
#    1,
#    -106.519,
#    39.6349,
#    90,
#    2022,
#    None,
#    'Avon, Vail & Eagle'],
#   ['eauclaire',
#    'Eau Claire, United States - ',
#    2,
#    -91.5106,
#    44.8152,
#    None,
#    None,
#    None,
#    ''],
#   ['eckenforde',
#    'Eckernfu00f6rde, Germany - SprottenFlotte',
#    3,
#    9.8276,
#    54.4727,
#    97,
#    2021,
#    2022,
#    ''],
#   ['ede', 'Ede, Nigeria - Awa Bike', 1, 4.457, 7.68472, 50, 2019, None, ''],
#   ['edessa',
#    'Edessa, Greece - Cyclo Edessa',
#    1,
#    22.0504,
#    40.8008,
#    20,
#    2020,
#    None,
#    ''],
#   ['edinagoldenvalley',
#    'Edina & Golden Valley, United States - Lime',
#    3,
#    -93.3563,
#    44.8909,
#    50,
#    2018,
#    2020,
#    ''],
#   ['edinburgh',
#    'Edinburgh, United Kingdom - Just Eat Cycles',
#    3,
#    -3.19016,
#    55.9537,
#    244,
#    2018,
#    2021,
#    ''],
#   ['edinburgh_nextbike',
#    'Edinburgh, United Kingdom - Nextbike',
#    3,
#    -3.3455,
#    55.9362,
#    17,
#    2017,
#    2017,
#    ''],
#   ['edmonton_blatchford',
#    'Edmonton, Canada - ',
#    6,
#    -113.516,
#    53.5717,
#    None,
#    None,
#    None,
#    'Blatchford District'],
#   ['edmonton_bird',
#    'Edmonton, Canada - Bird',
#    1,
#    -113.496,
#    53.5444,
#    200,
#    2022,
#    None,
#    ''],
#   ['edmonton_lime',
#    'Edmonton, Canada - Lime',
#    1,
#    -113.477,
#    53.5493,
#    200,
#    2022,
#    None,
#    ''],
#   ['eindhoven_gosharing',
#    'Eindhoven, Netherlands - GO Sharing',
#    1,
#    5.49167,
#    51.4368,
#    250,
#    2021,
#    None,
#    ''],
#   ['eindhoven',
#    'Eindhoven, Netherlands - Hopperpoint',
#    1,
#    5.47866,
#    51.4437,
#    120,
#    2016,
#    None,
#    ''],
#   ['eindhoven_tier',
#    'Eindhoven, Netherlands - TIER',
#    1,
#    5.4399,
#    51.4219,
#    616,
#    2021,
#    None,
#    'Eindhoven and Veldhoven'],
#   ['eisenstadt_nextbikeburgenland',
#    'Eisenstadt, Austria - Nextbike Burgenland',
#    1,
#    16.5253,
#    47.8493,
#    None,
#    2011,
#    None,
#    ''],
#   ['elcampello',
#    'El Campello, Spain - Onroll',
#    3,
#    -0.396495,
#    38.4287,
#    25,
#    2009,
#    2013,
#    ''],
#   ['elcerrito',
#    'El Cerrito, United States - Lime',
#    3,
#    -122.303,
#    37.9182,
#    100,
#    2018,
#    2019,
#    ''],
#   ['elgouna',
#    'El Gouna, Egypt - Baddel',
#    1,
#    33.6745,
#    27.3975,
#    300,
#    2017,
#    None,
#    ''],
#   ['elpaso',
#    'El Paso, United States - SunCycle',
#    1,
#    -106.488,
#    31.7605,
#    100,
#    2015,
#    None,
#    ''],
#   ['retiro',
#    'El Retiro, Colombia - MasBici',
#    1,
#    -75.5025,
#    6.06093,
#    41,
#    2022,
#    None,
#    ''],
#   ['elche',
#    'Elche, Spain - bicielx',
#    1,
#    -0.703297,
#    38.2677,
#    367,
#    2010,
#    None,
#    ''],
#   ['elkhart',
#    'Elkhart, United States - Lime',
#    3,
#    -85.9742,
#    41.685,
#    34,
#    2018,
#    2019,
#    ''],
#   ['ellmau',
#    'Ellmau, Austria - VVT REGIORAD Tirol',
#    1,
#    12.2524,
#    47.5194,
#    20,
#    2022,
#    None,
#    ''],
#   ['elmira',
#    'Elmira, United States - Lime',
#    3,
#    -76.8099,
#    42.0963,
#    None,
#    2018,
#    2019,
#    ''],
#   ['emeimountain',
#    'Emeishan City, China - Meituan Bike',
#    3,
#    103.469,
#    29.5866,
#    600,
#    2017,
#    2020,
#    ''],
#   ['encinitas',
#    'Encinitas, United States - BCycle',
#    1,
#    -117.289,
#    33.0514,
#    77,
#    2022,
#    None,
#    ''],
#   ['encinitassolonabeachdelmar',
#    'Encinitas, United States - Gotcha',
#    6,
#    -117.287,
#    33.0352,
#    500,
#    2019,
#    None,
#    'Encinitas, Solona Beach & Del Mar'],
#   ['enna', "Enna, Italy - velo'Enna", 3, 14.2767, 37.5598, 35, 2014, None, ''],
#   ['enschede',
#    'Enschede and Hengelo, Netherlands - Bondi',
#    1,
#    6.8353,
#    52.2444,
#    66,
#    2021,
#    None,
#    'Enschede and Hengelo'],
#   ['enschede_bolt',
#    'Enschede, Netherlands - Bolt',
#    1,
#    6.88468,
#    52.2146,
#    200,
#    2022,
#    None,
#    'Losser, Enschede'],
#   ['pinal',
#    'u00c9pinal, France - Vilvolt',
#    1,
#    6.4436,
#    48.1712,
#    150,
#    2021,
#    None,
#    'u00c9pinal, Golbey, Thaon, Charmes, La Vu00f4ge-les Bains'],
#   ['erfurt',
#    'Erfurt, Germany - nextbike',
#    3,
#    11.029,
#    50.9737,
#    79,
#    2009,
#    2023,
#    ''],
#   ['erie_county',
#    'Erie County, United States - Erie County Bike Share',
#    1,
#    -82.6994,
#    41.4247,
#    10,
#    2023,
#    None,
#    'Sandusky'],
#   ['erlangen',
#    'Erlangen, Germany - nextbike',
#    3,
#    11.0083,
#    49.5983,
#    None,
#    2009,
#    2012,
#    ''],
#   ['erlangen_nextbike2',
#    'Erlangen, Germany - nextbike by TIER',
#    1,
#    11.004,
#    49.588,
#    30,
#    2022,
#    None,
#    ''],
#   ['ermoupolis',
#    'Ermoupolis, Greece - Ermoupolis Public Bicycles',
#    1,
#    24.9436,
#    37.4442,
#    2,
#    2016,
#    None,
#    ''],
#   ['esch',
#    "Esch-sur-Alzette, Luxembourg - Vu00ebl'Ok",
#    1,
#    5.98253,
#    49.4973,
#    482,
#    2009,
#    None,
#    'Esch-sur-Alzette, Bettembourg, Differdange, Dudelange, Kayl, Rumelange, Sanem and Schifflange'],
#   ['estavayer',
#    'Estavayer-le-Lac, Switzerland - Publibike',
#    3,
#    6.84446,
#    46.8456,
#    15,
#    2011,
#    2018,
#    ''],
#   ['estepona',
#    'Estepona, Spain - Dott',
#    1,
#    -5.1459,
#    36.427,
#    37,
#    None,
#    None,
#    ''],
#   ['esztergom',
#    'Esztergom, Hungary - MV Bike',
#    1,
#    18.7434,
#    47.7893,
#    105,
#    2013,
#    None,
#    ''],
#   ['etellebruckdiekirch',
#    "Ettelbruck & Diekirch, Luxembourg - Citymov'",
#    3,
#    6.10711,
#    49.8484,
#    28,
#    2013,
#    2018,
#    ''],
#   ['eugene',
#    'Eugene, United States - PeaceHealth Rides',
#    1,
#    -123.085,
#    44.0419,
#    350,
#    2018,
#    None,
#    ''],
#   ['eupen',
#    'Eupen, Belgium - Velocity',
#    6,
#    6.03407,
#    50.631,
#    None,
#    2019,
#    None,
#    'Eupen, La Calamine, Lontzen and Raeren'],
#   ['evansville',
#    'Evansville, United States - Upgrade Bikes',
#    3,
#    -87.5497,
#    37.9737,
#    100,
#    2016,
#    2019,
#    ''],
#   ['evansville_bloom',
#    'Evansville, United States - Upgrade Bikes',
#    1,
#    -87.5497,
#    37.9737,
#    70,
#    2021,
#    None,
#    ''],
#   ['everett',
#    'Everett, United States - Lime',
#    3,
#    -71.0527,
#    42.4065,
#    300,
#    2018,
#    2019,
#    ''],
#   ['evian_fredo',
#    'u00c9vian-les-Bains, France - Fredo',
#    1,
#    6.58173,
#    46.3938,
#    44,
#    2023,
#    None,
#    ''],
#   ['exeter',
#    'Exeter, United Kingdom - Co BIkes',
#    3,
#    -3.54249,
#    50.7292,
#    146,
#    2016,
#    2023,
#    'Exeter, Cranbrook, Exmouth and Honiton'],
#   ['ezhou',
#    'Ezhou, China - Meituan Bike',
#    3,
#    114.893,
#    30.3962,
#    None,
#    2017,
#    2020,
#    ''],
#   ['fafe', 'Fafe, Portugal - ', 2, -8.17127, 41.4506, 30, None, None, ''],
#   ['fairbanks',
#    'Fairbanks, United States - Fairbikes',
#    3,
#    -147.769,
#    64.8467,
#    50,
#    2016,
#    2018,
#    ''],
#   ['fairfax',
#    'Fairfax, United States - Patriot Bike Share',
#    3,
#    -77.3067,
#    38.8301,
#    20,
#    2012,
#    2013,
#    ''],
#   ['falmouth',
#    'Falmouth, United Kingdom - Beryl Bikes',
#    1,
#    -5.0728,
#    50.1538,
#    52,
#    2022,
#    None,
#    'Falmouth'],
#   ['falmouth_cobikes',
#    'Falmouth, United Kingdom - Co Bikes',
#    3,
#    -5.1175,
#    50.1621,
#    52,
#    2021,
#    2022,
#    ''],
#   ['famagusta',
#    'Famagusta, Cyprus - Velespeed',
#    1,
#    33.9308,
#    35.1297,
#    68,
#    2019,
#    None,
#    ''],
#   ['fangchenggang',
#    'Fangchenggang, China - Public Bicycle Rental System',
#    1,
#    108.355,
#    21.6812,
#    60,
#    2016,
#    None,
#    ''],
#   ['fano',
#    "Fano, Italy - C'entro in Bici!",
#    3,
#    13.0202,
#    43.8444,
#    40,
#    2013,
#    2020,
#    ''],
#   ['fargo',
#    'Fargo, United States - Great Rides Bikeshare',
#    5,
#    -96.793,
#    46.8808,
#    107,
#    2015,
#    None,
#    ''],
#   ['faridabad',
#    'Faridabad, India - ',
#    6,
#    77.3214,
#    28.3926,
#    None,
#    None,
#    None,
#    ''],
#   ['farnborough',
#    'Farnborough, United Kingdom - OYBike',
#    3,
#    -0.753765,
#    51.2952,
#    30,
#    2008,
#    2011,
#    ''],
#   ['faro',
#    'Faro, Portugal - Bird',
#    2,
#    -7.93186,
#    37.0166,
#    None,
#    2019,
#    None,
#    ''],
#   ['fayetteville',
#    'Fayetteville, United States - Spin',
#    1,
#    -78.8778,
#    35.0524,
#    49,
#    None,
#    None,
#    ''],
#   ['feicounty',
#    'Feixian, China - Feixian Public Bicycle',
#    1,
#    117.997,
#    35.2656,
#    1100,
#    2014,
#    None,
#    'Fei County (Feixian)'],
#   ['feltre', 'Feltre, Italy - ', 3, 11.9099, 46.0127, 0, 2016, None, ''],
#   ['fengtai', 'Fengtai, China - ', 1, 116.693, 32.7272, 500, 2017, None, ''],
#   ['fenhu',
#    'Fenhu, China - Wujiang Public Bicycle',
#    1,
#    120.847,
#    31.041,
#    760,
#    2013,
#    None,
#    'Fenhu'],
#   ['fergusfalls',
#    'Fergus Falls, United States - ',
#    2,
#    -96.0761,
#    46.2844,
#    None,
#    None,
#    None,
#    ''],
#   ['ferrara',
#    'Ferrara, Italy - Dott',
#    1,
#    11.5922,
#    44.8618,
#    82,
#    2021,
#    None,
#    ''],
#   ['ferrara_mimuovoinbici',
#    'Ferrara, Italy - Mi Muovo in bici',
#    1,
#    11.62,
#    44.8387,
#    70,
#    2013,
#    None,
#    ''],
#   ['ferrara_mobike',
#    'Ferrara, Italy - Movi by Mobike',
#    1,
#    11.5603,
#    44.8348,
#    150,
#    2019,
#    None,
#    ''],
#   ['ferrol',
#    'Ferrol, Spain - Bici Ferrolterra',
#    1,
#    -8.21915,
#    43.4883,
#    110,
#    2007,
#    None,
#    ''],
#   ['fieradiprimiero',
#    'Fiera di Primiero, Italy - Green way Bike',
#    3,
#    11.8299,
#    46.1829,
#    11,
#    2013,
#    None,
#    'Canal San Bovo, Imer, San Martino di Castrozza & Siror'],
#   ['figueira',
#    'Figueira da Foz, Portugal - Figas',
#    1,
#    -8.8637,
#    40.1537,
#    50,
#    2020,
#    None,
#    ''],
#   ['fingal',
#    'Fingal, Ireland - TIER',
#    1,
#    -6.2285,
#    53.4323,
#    140,
#    2022,
#    None,
#    ''],
#   ['flagstaff',
#    'Flagstaff, United States - Spin',
#    3,
#    -111.652,
#    35.196,
#    300,
#    2018,
#    2018,
#    ''],
#   ['flensburg',
#    'Flensburg, Germany - nextbike',
#    3,
#    9.43992,
#    54.7801,
#    31,
#    2009,
#    2019,
#    ''],
#   ['flint',
#    'Flint, United States - Flint Bike Share',
#    3,
#    -83.6863,
#    43.0104,
#    19,
#    2016,
#    2020,
#    ''],
#   ['florence_gobee',
#    'Florence, Italy - GoBee',
#    3,
#    11.2572,
#    43.7719,
#    400,
#    2017,
#    2018,
#    ''],
#   ['florence_mobike',
#    'Florence, Italy - RideMovi',
#    1,
#    11.2972,
#    43.7691,
#    2000,
#    2017,
#    None,
#    'Florence, Sesto Fiorentino, Scandicci and Bagno a Ripoli'],
#   ['florianopolis_tembici',
#    'Florianu00f3polis, Brazil - Bike Estu00e1cio',
#    1,
#    -48.5534,
#    -27.5923,
#    100,
#    2023,
#    None,
#    ''],
#   ['florianopolis_floripabike',
#    'Florianu00f3polis, Brazil - Bike Floripa',
#    6,
#    -48.5534,
#    -27.5923,
#    830,
#    None,
#    None,
#    ''],
#   ['florianopolis_yellow',
#    'Florianu00f3polis, Brazil - Yellow',
#    3,
#    -48.5778,
#    -27.5956,
#    215,
#    2018,
#    2020,
#    ''],
#   ['florina',
#    'Florina, Greece - Cyclopolis Florina',
#    3,
#    21.4135,
#    40.7853,
#    90,
#    2015,
#    2019,
#    ''],
#   ['focsani',
#    'Focu0219ani, Romania - ',
#    2,
#    27.1873,
#    45.6948,
#    285,
#    None,
#    None,
#    ''],
#   ['foggia',
#    'Foggia, Italy - Foggia by Bike',
#    1,
#    15.5368,
#    41.4632,
#    80,
#    2011,
#    None,
#    ''],
#   ['folkestone',
#    'Folkestone and Hythe, United Kingdom - Click2Cycle',
#    1,
#    1.1295,
#    51.0761,
#    35,
#    2018,
#    None,
#    ''],
#   ['fonddulac',
#    'Fond du Lac, United States - ',
#    2,
#    -88.4033,
#    43.8067,
#    None,
#    None,
#    None,
#    ''],
#   ['forestcity',
#    'Forest City, United States - Lime',
#    3,
#    -122.275,
#    37.5598,
#    50,
#    2018,
#    None,
#    ''],
#   ['forli',
#    'Forlu00ec, Italy - Mi Muovo in bici',
#    1,
#    12.0493,
#    44.2196,
#    86,
#    2012,
#    None,
#    ''],
#   ['fortcollins',
#    'Fort Collins, United States - Fort Collins Bike Share',
#    3,
#    -105.076,
#    40.5861,
#    99,
#    2016,
#    2020,
#    ''],
#   ['fortcollins_spin',
#    'Fort Collins, United States - Spin',
#    1,
#    -105.08,
#    40.5542,
#    192,
#    None,
#    None,
#    ''],
#   ...],
#  'result2': {'thecount': 9024552},
#  'result3': {'lastmoddt': '30 Dec 2023'}}

# %%
# Vybrat pouze klíč 'result' pro vytvoření DataFrame
result_data = data['result']

# Seznam názvů sloupců
columns = ["id", "name_station","num_of_stations", "lon", "lat", "num_of_bikes", "launch", "terminated", "None"]

# Vytvoření DataFrame
df = pd.DataFrame(result_data, columns=columns)
df
# Out:
#                    id                                       name_station  \
# 0             acoruna               A Coruu00f1a, Spain - Bicicoruu00f1a
# 1              aachen                      Aachen, Germany - Call a Bike
# 2     aachen_velocity                  Aachen, Germany - Velocity Aachen
# 3             aalborg                      Aalborg, Denmark - City Bikes
# 4      aalborg_donkey                 Aalborg, Denmark - Donkey Republic
# ...               ...                                                ...
# 3789             lask        u0141ask, Poland - Rowerowe u0141u00f3dzkie
# 3790             lodz  u0141u00f3du017a, Poland - Rowerowe u0141u00f3...
# 3791    lodz_freebike  u0141u00f3du017a, Poland - u0141u00f3du017a Fr...
# 3792            lomza                      u0141omza, Poland - u0141oKeR
# 3793           lowicz      u0141owicz, Poland - Rowerowe u0141u00f3dzkie
#
#       num_of_stations       lon      lat  num_of_bikes  launch  terminated  \
# 0                   1  -8.39626  43.3723         396.0  2009.0         NaN
# 1                   3   6.09200  50.7692          15.0  2011.0      2014.0
# 2                   1   6.06720  50.7789         300.0  2016.0         NaN
# 3                   3   9.92134  57.0437         170.0  2009.0      2014.0
# 4                   1   9.92116  57.0503          72.0  2017.0         NaN
# ...               ...       ...      ...           ...     ...         ...
# 3789                1  19.13850  51.5899          49.0  2018.0         NaN
# 3790                4  19.46020  51.7600         137.0  2016.0         NaN
# 3791                1  19.49220  51.7835        1399.0  2021.0         NaN
# 3792                1  22.05580  53.1778         129.0  2022.0         NaN
# 3793                1  19.95200  52.1056          96.0  2018.0         NaN
#
#      None
# 0
# 1
# 2
# 3
# 4
# ...   ...
# 3789
# 3790
# 3791
# 3792
# 3793
#
# [3794 rows x 9 columns]

# %%
# df.to_excel('BikesharingWorldMap.xlsx', index=False)

# %% [markdown]
# # Lower code is useless so far

# %%
# conversion to a 2D list

cleaned_data_lst = json.loads(cleaned_data)
len(cleaned_data_lst)
#print(cleaned_data_lst)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [18], line 3
#       1 # conversion to a 2D list
# ----> 3 cleaned_data_lst = json.loads(cleaned_data)
#       4 len(cleaned_data_lst)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 1 column 87 (char 86)

# %%
#cleaned_data_lst

# %%
name_cols = ["id", "name_station","num_of_stations", "lon", "lat", "num_of_bikes", "launch", "terminated"]

# %%
df1 = pd.DataFrame(cleaned_data_lst, columns=name_cols)

# %%
df1.set_index('id', inplace=True)

# %%
df1.shape
# Out:
# (3314, 7)

# %%
# df1.to_excel("df1_Company_Points_bikesharingworldmap.xlsx")

# %% [markdown]
# ## Creation of the 2nd DataFrame - rotation of IDs in the request

# %%
def point_info(ad_id):
    
    headers = {
        'Connection': 'keep-alive',
        'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="97", "Chromium";v="97"',
        'Accept': 'application/json, text/javascript, */*; q=0.01',
        'X-Requested-With': 'XMLHttpRequest',
        'sec-ch-ua-mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
        'sec-ch-ua-platform': '"Windows"',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://bikesharingworldmap.com/',
        'Accept-Language': 'cs-CZ,cs;q=0.9',
    }
    
    params = (
        ('system', f'{ad_id}'),
    )

    response = requests.get('https://bikesharingworldmap.com/getsystem.php', headers=headers, params=params)
    return response.json()

# %%
# [i for lst in cleaned_data_lst for i in lst]

# %%
# Extrakce IDs
"""
for lst in cleaned_data_lst:
    for i in lst:
        print(i)
        
# list comprehension
[i for lst in cleaned_data_lst for i in lst]
"""

ids_lst = [i[0] for i in cleaned_data_lst]
len(ids_lst)
ids_lst[0:10]
# Out:
# ['acoruna',
#  'aachen',
#  'aachen_velocity',
#  'aalborg',
#  'aalborg_donkey',
#  'aarhus',
#  'aarhus_donkey',
#  'aberdeen',
#  'abudhabi',
#  'abudhabi_careem']

# %%
#vytvoření listu pro informace ke stanicím a následné jeho plnění slovníky s infem o bodech
datetime.now().strftime("%d/%m/%Y %H:%M:%S")

point_info_list = []
for _id in ids_lst:
    # print(_id)
    info_pts = point_info(_id)
    point_info_list.append(info_pts)
    
datetime.now().strftime("%d/%m/%Y %H:%M:%S")

# %%
# očištění výsledného slovníku a připojení očištěných dat do nového listu
clean_pt_lst = []
for i in point_info_list:
    for k, v in i.items():
        if k == "result":
            clean_pt_lst.append(v)
            
# stejný zápis jen pomocí list comprehension
clean_pt_lst = [v for i in point_info_list for k, v in i.items() if k == "result"]

# %%
name_cols_2 = ["id", "city_company","a", "bikes", "stations", "inc_pedelecs", "b", "c", "web_company", "d", "working", "date_launch", "date_terminated", "e", "operator", "equipment", "f", "pic", "g"]

# %%
len(name_cols_2)
# Out:
# 19

# %%
df2 = pd.DataFrame(clean_pt_lst, columns=name_cols_2)

# %%
df2.set_index("id", inplace=True)

# %%
df2.shape
# Out:
# (3292, 18)

# %%
df1.shape[0]-df2.shape[0]
# Out:
# 22

# %%
#df2.to_excel("df2_Company_Points_bikesharingworldmap.xlsx")

# %% [markdown]
# - Joining DF1 a DF2

# %%
# pd.concat([df1, df2], join="inner", axis=1)

# %%
df3 = df1.join(df2, rsuffix="_sec", how="left")

# %%
df3
# Out:
#                                                    name_station  \
# id
# Chilecito                  Chilecito, Argentina - Rioja en Bici
# Cycle!        Glens Falls, Queensbury and Lake George, Unite...
# Gizycko                                  Gizycko, Poland - GROM
# Kumagaya                   Kumagaya, Japan - Wild Knights Cycle
# Maebashi                          Maebashi, Japan - Akagi cogbe
# ...                                                         ...
# zurich                  Zu00fcrich, Switzerland - Zu00fcri Velo
# zurich_lime                      Zu00fcrich, Switzerland - Lime
# zurich_obike                    Zu00fcrich, Switzerland - oBike
# zurich_smide                     Zu00fcrich, Switzerland - bond
# zyrardow      u017byrardu00f3w, Poland - u017byrardowski Row...
#
#               num_of_stations        lon      lat  num_of_bikes  launch  \
# id
# Chilecito                   2  -67.49520 -29.1598           NaN     NaN
# Cycle!                      1  -73.64500  43.3094          20.0     NaN
# Gizycko                     4   21.76840  54.0363          20.0  2018.0
# Kumagaya                    1  139.37400  36.1624         100.0  2021.0
# Maebashi                    1  139.12300  36.4346           NaN  2021.0
# ...                       ...        ...      ...           ...     ...
# zurich                      1    8.53822  47.3823         350.0  2018.0
# zurich_lime                 1    8.54105  47.3720         560.0  2018.0
# zurich_obike                3    8.54084  47.3676         700.0  2017.0
# zurich_smide                1    8.53964  47.3707         250.0  2016.0
# zyrardow                    4   20.44610  52.0516          40.0  2018.0
#
#               terminated                                city_company a  bikes  \
# id
# Chilecito            NaN                   Chilecito - Rioja en Bici     None
# Cycle!               NaN  Glens Falls, Queensbury and Lake George -        20
# Gizycko              NaN                              Gizycko - GROM       20
# Kumagaya             NaN               Kumagaya - Wild Knights Cycle      100
# Maebashi             NaN                      Maebashi - Akagi cogbe     None
# ...                  ...                                         ... ..   ...
# zurich               NaN                          Zürich - Züri Velo      350
# zurich_lime          NaN                               Zürich - Lime      560
# zurich_obike      2018.0                              Zürich - oBike      700
# zurich_smide         NaN                               Zürich - bond      250
# zyrardow             NaN        Żyrardów - Żyrardowski Rower Miejski       40
#
#               ... d   working date_launch date_terminated  \
# id            ...
# Chilecito     ...        None        None            None
# Cycle!        ...      208614        None            None
# Gizycko       ...      134135  2018-07-23            None
# Kumagaya      ...     1002160  2021-09-16            None
# Maebashi      ...      101700  2021-10-23            None
# ...           ... ..      ...         ...             ...
# zurich        ...           0  2018-04-06            None
# zurich_lime   ...           0  2018-01-04            None
# zurich_obike  ...           0  2017-07-07      2018-06-29
# zurich_smide  ...           0  2016-11-10            None
# zyrardow      ...           0  2018-10-01            None
#
#                                                e          operator  equipment  \
# id
# Chilecito
# Cycle!                                                       CDPHP
# Gizycko                                                     ROOVEE     ROOVEE
# Kumagaya
# Maebashi                                                   Ecobike
# ...                                          ...               ...        ...
# zurich                                                   Publibike  Publibike
# zurich_lime                                                   Lime   Limebike
# zurich_obike
# zurich_smide                                         Bond Mobility      Smide
# zyrardow      https://bikesharemap.com/zyrardow/  Nextbike Poland   Nextbike
#
#              f                                                 pic g
# id
# Chilecito
# Cycle!           https://poststar.com/news/local/bike-sharing-p...
# Gizycko          https://mazury24.eu/aktualnosci/rowerem-miejsk...
# Kumagaya                 https://kumagaya.keizai.biz/headline/957/
# Maebashi         https://prtimes.jp/main/html/rd/p/000000008.00...
# ...          ..                                                ... ..
# zurich
# zurich_lime
# zurich_obike
# zurich_smide
# zyrardow
#
# [3319 rows x 25 columns]

# %%
df3.columns
# Out:
# Index(['name_station', 'num_of_stations', 'lon', 'lat', 'num_of_bikes',
#        'launch', 'terminated', 'city_company', 'a', 'bikes', 'stations',
#        'inc_pedelecs', 'b', 'c', 'web_company', 'd', 'working', 'date_launch',
#        'date_terminated', 'e', 'operator', 'equipment', 'f', 'pic', 'g'],
#       dtype='object')

# %%
df3.loc[:, ["lon", "lat"]].dtypes
# Out:
# lon    float64
# lat    float64
# dtype: object

# %%
#df3.to_excel("df3_Company_Points_bikesharingworldmap.xlsx")

# %%
geometry = [Point(LonLat) for LonLat in zip(df3.lon, df3.lat)]
crs = {'init': 'epsg:4326'}
geo_df = GeoDataFrame(df3, crs=crs, geometry=geometry)

#geo_df.to_file(driver='ESRI Shapefile', filename='Company_Points_bikesharingworldmap.shp')
# Out:
# C:\Users\Milan\anaconda3\lib\site-packages\geopandas\geodataframe.py:35: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   out = from_shapely(data)
